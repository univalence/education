// %% [markdown]
// ![Spark Logo](http://spark-mooc.github.io/web-assets/images/ta_Spark-logo-small.png)

// %% [markdown]
// # Distributed computation
// ## ESIPE — INFO 3 — Option Logiciel

// %% [markdown]
// # Lab 1:  Word Count with Spark

// %% [markdown]
// This lab will enable us to develop a simple word count application.  The volume of unstructured text in existence is growing dramatically, and Spark is an excellent tool for analyzing this type of data.  In this lab, we will write code that calculates the most common words in the [Complete Works of William Shakespeare](http://www.gutenberg.org/ebooks/100) retrieved from [Project Gutenberg](http://www.gutenberg.org/wiki/Main_Page).  This could also be scaled to find the most common words on the Internet.
//
// **During this lab we will cover:**
//
// - **Part 1:** Word Count with RDDs  -- You will play with basic RDDs, then build a pair RDD, use it for counting words. Finally you will learn how to clean and prepare the RDD and build the application to count words in a file.
//
// - **Part 2:** is devoted to a small tutorial on Spark Dataframes (introduced in Spark 1.3)
//
// - **Part 3:** Word Count with dataframes -- You will follow the same steps as in Part 1 to develop a Word Counting application and apply it to a file.
//
//
// **Exercises** will include an explanation of what is expected, followed by code cells where one cell will have one or more `???` sections.  The cell that needs to be modified will have `// TODO: Replace ??? with appropriate code` on its first line.  Once the `???` sections are updated and the code is run, the test cell can then be run to verify the correctness of your solution.  The last code cell before the next markdown section will contain the tests.
//
// Note that, for reference, you can look up the details of the relevant methods in [Spark's Scala API](https://spark.apache.org/docs/latest/api/scala/index.html#org.apache.spark.package)

// %% [markdown]
// ##  Prerequisites: Spark Context configuration

// %% [markdown]
// The current text stands inside a structure named a cell. This cell is a **text cell**, that can only contain text with [Markdown format](https://en.wikipedia.org/wiki/Markdown). You can double-click on it and change its content. Once you have finished to edit the cell, hit `<Shift>+<Enter>` to render its content.
//
// Notice that you can save the current notebook at any moment by hitting the save icon in the toolbar or in menu "File > Save and Checkpoint".
//
// The cell below differs: it is a **code cell**. You can directly write in. The current Jupyter instance is configured to work with Apache Spark and Scala (it uses a kind of driver named [Apache Toree](https://toree.apache.org/)). So you can write Scala / Spark code in code cells.
//
// The following cell contains code to initialize a SparkSession and a SparkContext. Select the cell below and hit `<Shift>+<Enter>` to evaluate its content (it may take some times, do not worry).

// %%
import org.apache.spark._

val spark = SparkSession.builder
  .appName("lab1_word_count_text")
  .master("local[*]")
  .getOrCreate()

val sc = spark.sparkContext
// Out:
// spark = org.apache.spark.sql.SparkSession@7b437f09
// sc = org.apache.spark.SparkContext@1161ac33
// org.apache.spark.SparkContext@1161ac33
// bombast: 2
// contemptible: 2
// examind: 2
// incertainties: 2
// austerely: 2
// erected: 2
// displacd: 2
// descending: 2
// asketh: 2
// unstaind: 2
// claudius: 2
// astray: 2
// unstate: 2
// eaves: 2
// permitted: 2
// quire: 2
// saddest: 2
// judgmentday: 2
// yarely: 2
// thronging: 2
// subtleties: 2
// confessed: 2
// infamous: 2
// partlet: 2
// misleader: 2
// twentieth: 2
// wiles: 2
// unheedful: 2
// sur: 2
// intellectual: 2
// pinching: 2
// angellike: 2
// outfacing: 2
// whenever: 2
// replying: 2
// keech: 2
// haild: 2
// decide: 2
// aweless: 2
// thumpd: 2
// differing: 2
// leave: 651
// down: 654
// name: 655
// being: 662
// other: 669
// eyes: 690
// son: 691
// been: 697
// two: 702
// any: 705
// old: 711
// day: 719
// pray: 730
// prince: 742
// fair: 757
// cannot: 761
// ay: 764
// master: 765
// again: 768
// own: 771
// god: 773
// thus: 781
// sweet: 789
// true: 792
// scene: 795
// very: 813
// made: 824
// look: 828
// life: 834
// before: 835
// father: 836
// hand: 838
// men: 853
// away: 856
// death: 858
// lady: 864
// hear: 871
// great: 899
// art: 915
// doth: 939
// queen: 943
// nor: 968
// exit: 984
// heart: 985
// never: 1011
// think: 1024
// exeunt: 1035
// much: 1035
// time: 1046
// tell: 1059
// up: 1068
// duke: 1071
// th: 1148
// first: 1159
// mine: 1161
// speak: 1165
// most: 1181
// take: 1197
// who: 1202
// can: 1208
// too: 1232
// where: 1232
// these: 1322
// give: 1327
// some: 1337
// out: 1376
// such: 1390
// tis: 1405
// had: 1427
// see: 1438
// why: 1465
// must: 1491
// yet: 1569
// should: 1572
// were: 1577
// us: 1621
// did: 1626
// make: 1629
// may: 1633
// know: 1647
// say: 1680
// like: 1701
// upon: 1731
// go: 1733
// one: 1779
// there: 1808
// an: 1832
// man: 1835
// than: 1879
// hath: 1941
// ill: 1972
// them: 1978
// when: 2049
// love: 2053
// their: 2075
// enter: 2098
// let: 2099
// here: 2114
// how: 2159
// am: 2168
// she: 2208
// then: 2221
// was: 2229
// more: 2288
// would: 2293
// which: 2315
// or: 2425
// well: 2462
// they: 2471
// at: 2501
// come: 2507
// o: 2607
// from: 2639
// sir: 2754
// now: 2778
// good: 2812
// king: 2861
// on: 3046
// lord: 3059
// our: 3061
// thee: 3178
// we: 3296
// are: 3403
// if: 3493
// shall: 3591
// by: 3729
// do: 3748
// no: 3790
// her: 3843
// all: 3883
// thy: 4032
// what: 4464
// will: 4974
// so: 5044
// him: 5192
// thou: 5485
// as: 5733
// have: 5880
// he: 6251
// but: 6265
// this: 6602
// your: 6655
// his: 6857
// be: 6857
// for: 7558
// it: 7678
// me: 7769
// with: 7771
// not: 8497
// is: 9134
// that: 10890
// in: 10956
// my: 12481
// you: 13615
// a: 14593
// of: 17463
// to: 19150
// i: 20681
// and: 26028
// the: 27361
// : 44635

// %% [markdown]
// Good! The Spark session is initialized. The current notebook is associated to a local application named `lab1_word_count_text` and we have allocated all the available cores to it (due to `local[*]` declaration in master configuration).
//
// This also means that a Spark UI (ie. the Spark application metrics Web interface) has been launched. It is available at the URL http://localhost:4040/. Do not hesitate to take a look!
//
// ... Quite empty, isn't it? As we do not have sent any task, it is almost obvious that Spark UI does not report any metrics. The rest of the notebook will provide some metrics to Spark UI. Do not hesitate to take a look time to time to Spark UI during this lab.

// %% [markdown]
// # Part 1: Word Count with RDDs
//
// ##  1. Creating a base RDD and pair RDDs
//
// We will first explore creating a base RDD with `parallelize` and using pair RDDs to count words.
//
// ### (1a) Create a base RDD
//
// We'll start by generating a base RDD by using a List and the `sc.parallelize` method.  Then we'll print out the type of the base RDD.

// %%
val wordsList = List("cat", "elephant", "rat", "rat", "cat")
val wordsRDD = sc.parallelize(wordsList, 4)
// Print out the type of wordsRDD
println(wordsRDD.getClass)
// Out:
// class org.apache.spark.rdd.ParallelCollectionRDD
// wordsList = List(cat, elephant, rat, rat, cat)
// wordsRDD = ParallelCollectionRDD[0] at parallelize at <console>:31
// ParallelCollectionRDD[0] at parallelize at <console>:31

// %% [markdown]
// ### (1b) Pluralize and test
//
// Let's use a `map()` transformation to add the letter 's' to each string in the base RDD we just created. We'll define a function that returns the word with an 's' at the end of the word.  Please replace `???` with your solution.  If you have trouble, the next cell has the solution.  After you have defined `makePlural` you can run the third cell which contains a test.  If you implementation is correct it will print `1 test passed`.
//
// This is the general form that exercises will take, except that no example solution will be provided.

// %%
//TODO: Replace ??? with appropriate code
def makePlural(word : String): String = {
    /*Adds an 's' to `word`.

    Note:
        This is a simple function that only adds an 's'.  No attempt is made to follow proper
        pluralization rules.

    Args:
        word (str): A string.

    Returns:
        str: A string with 's' added to it.
    */
    return s"${word}s"
}
    

print(makePlural("cat"))
// Out:
// makePlural: (word: String)String
// cats

// %%
//One way of completing the function
val makePlural = (word : String) => 
    word + "s"

print(makePlural("cat"))
// Out:
// cats
// makePlural = > String = <function1>
// > String = <function1>

// %%
def assertResult[A](expected : A, error : String)(answer : A) = {
    if (expected equals answer) "1 test passed"
    else error
}
// Out:
// assertResult: [A](expected: A, error: String)(answer: A)String

// %%
/*
# Load in the testing code and check to see if your answer is correct
# Make sure to rerun any cell you change before trying the test again
*/

//TEST Pluralize and test (1b)
assertResult("rats", "incorrect result: makePlural does not add an s") {
  makePlural("rat")
}
// Out:
// 1 test passed

// %% [markdown]
// ### (1c) Apply `makePlural` to the base RDD
//
// Now pass each item in the base RDD into a [map()](https://spark.apache.org/docs/latest/api/scala/index.html#org.apache.spark.rdd.RDD@map[U](f:T=%3EU)(implicitevidence$3:scala.reflect.ClassTag[U]):org.apache.spark.rdd.RDD[U]) transformation that applies the `makePlural()` function to each element. And then call the [collect()](https://spark.apache.org/docs/latest/api/scala/index.html#org.apache.spark.rdd.RDD@collect():Array[T]) action to see the transformed RDD.

// %%
// TODO: Replace ??? with appropriate code
val pluralRDD = wordsRDD.map(makePlural)
pluralRDD.collect().foreach(println)
// Out:
// cats
// elephants
// rats
// rats
// cats
// pluralRDD = MapPartitionsRDD[1] at map at <console>:33
// MapPartitionsRDD[1] at map at <console>:33

// %%
//TEST Apply makePlural to the base RDD(1c)
assertResult(List("cats", "elephants", "rats", "rats", "cats"), "incorrect values for pluralRDD") {
      pluralRDD.collect.toList
    }
// Out:
// 1 test passed

// %% [markdown]
// ### (1d) Pass a `lambda` function to `map`
//
// Let's create the same RDD using a `lambda` function.

// %%
// TODO: Replace ??? with appropriate code
val pluralLambdaRDD = wordsRDD.map(w => w + "s")
pluralLambdaRDD.collect().foreach(println)
// Out:
// cats
// elephants
// rats
// rats
// cats
// pluralLambdaRDD = MapPartitionsRDD[2] at map at <console>:31
// MapPartitionsRDD[2] at map at <console>:31

// %%
//TEST Pass a lambda function to map (1d)
assertResult(List("cats", "elephants", "rats", "rats", "cats"), "incorrect values for pluralLambdaRDD (1d)") {
    pluralLambdaRDD.collect.toList
}
// Out:
// 1 test passed

// %% [markdown]
// ### (1e) Length of each word
//
// Now use `map()` and a `lambda` function to return the number of characters in each word.  We'll `collect` this result directly into a variable.

// %%
// TODO: Replace ??? with appropriate code
val pluralLengths = pluralRDD
  .map(_.size)
  .collect
pluralLengths.foreach(println)
// Out:
// 4
// 9
// 4
// 4
// 4
// pluralLengths = Array(4, 9, 4, 4, 4)
// Array(4, 9, 4, 4, 4)

// %%
// TEST Length of each word (1e)
assertResult(List(4, 9, 4, 4, 4), "incorrect values for pluralLengths") {
  pluralLengths.toList
}
// Out:
// 1 test passed

// %% [markdown]
// ### (1f) Pair RDDs
//
// The next step in writing our word counting program is to create a new type of RDD, called a pair RDD. A pair RDD is an RDD where each element is a pair tuple `(k, v)` where `k` is the key and `v` is the value. In this example, we will create a pair consisting of `('<word>', 1)` for each word element in the RDD.
//
// We can create the pair RDD using the `map()` transformation with a `lambda()` function to create a new RDD.

// %%
// TODO: Replace ??? with appropriate code
val wordPairs = wordsRDD.map(w => (w, 1))
wordPairs.collect.foreach(println)
// Out:
// (cat,1)
// (elephant,1)
// (rat,1)
// (rat,1)
// (cat,1)
// wordPairs = MapPartitionsRDD[4] at map at <console>:31
// MapPartitionsRDD[4] at map at <console>:31

// %%
assertResult(List(("cat", 1), ("elephant", 1), ("rat", 1), ("rat", 1), ("cat", 1)), "incorrect values for wordPairs") {
  wordPairs.collect.toList
}
// Out:
// 1 test passed

// %% [markdown]
// ## 2. Counting with pair RDDs

// %% [markdown]
// Now, let's count the number of times a particular word appears in the RDD. There are multiple ways to perform the counting, but some are much less efficient than others.
//
// A naive approach would be to `collect()` all of the elements and count them in the driver program. While this approach could work for small datasets, we want an approach that will work for any size dataset including terabyte- or petabyte-sized datasets. In addition, performing all of the work in the driver program is slower than performing it in parallel in the workers. For these reasons, we will use data parallel operations.

// %% [markdown]
// ### (2a) `groupByKey()` approach
//
// An approach you might first consider (we'll see shortly that there are better ways) is based on using the [groupByKey()](https://spark.apache.org/docs/latest/api/scala/index.html#org.apache.spark.rdd.PairRDDFunctions@groupByKey():org.apache.spark.rdd.RDD[(K,Iterable[V])]) transformation. As the name implies, the `groupByKey()` transformation groups all the elements of the RDD with the same key into a single list in one of the partitions. There are two problems with using `groupByKey()`:
//   + The operation requires a lot of data movement to move all the values into the appropriate partitions.
//   + The lists can be very large. Consider a word count of English Wikipedia: the lists for common words (e.g., the, a, etc.) would be huge and could exhaust the available memory in a worker.
//
// Use `groupByKey()` to generate a pair RDD of type `('word', iterable)`.

// %%
// TODO: Replace ??? with appropriate code
// Note that groupByKey requires no parameters
val wordsGrouped = wordPairs.groupByKey()
val keyValues = wordsGrouped.collect
keyValues.foreach(x => println(x._1,x._2))
// Out:
// (rat,CompactBuffer(1, 1))
// (elephant,CompactBuffer(1))
// (cat,CompactBuffer(1, 1))
// wordsGrouped = ShuffledRDD[10] at groupByKey at <console>:35
// keyValues = Array((rat,CompactBuffer(1, 1)), (elephant,CompactBuffer(1)), (cat,CompactBuffer(1, 1)))
// Array((rat,CompactBuffer(1, 1)), (elephant,CompactBuffer(1)), (cat,CompactBuffer(1, 1)))

// %%
// TEST groupByKey() approach (2a)
assertResult(List(("cat", List(1, 1)), ("elephant", List(1)), ("rat", List(1, 1))),
"incorrect value for wordsGrouped") {
  wordsGrouped.mapValues(_.toList).collect.sortBy(_._1).toList
}
// Out:
// 1 test passed

// %% [markdown]
// ### (2b) Use `groupByKey()` to obtain the counts
//
// Using the `groupByKey()` transformation creates an RDD containing 3 elements, each of which is a pair of a word and an Iterable.
// Now sum the Iterable using a `map()` transformation.  The result should be a pair RDD consisting of (word, count) pairs.

// %%
// TODO: Replace ??? with appropriate code
val wordCountsGrouped = wordsGrouped.map { case (k, v) => k -> v.sum }
wordCountsGrouped.collect.foreach(println)
// Out:
// (rat,2)
// (elephant,1)
// (cat,2)
// wordCountsGrouped = MapPartitionsRDD[17] at map at <console>:33
// MapPartitionsRDD[17] at map at <console>:33

// %%
// TEST Use groupByKey() to obtain the counts (2b)
assertResult(List(("cat", 2), ("elephant", 1), ("rat", 2)),
"incorrect value for wordCountsGrouped") {
  wordCountsGrouped.collect.sortBy(_._1).toList
}
// Out:
// 1 test passed

// %% [markdown]
// ### (2c) Counting using `reduceByKey`
//
// A better approach is to start from the pair RDD and then use the [reduceByKey()](https://spark.apache.org/docs/latest/api/scala/index.html#org.apache.spark.rdd.PairRDDFunctions@reduceByKey(func:(V,V)=%3EV):org.apache.spark.rdd.RDD[(K,V)]) transformation to create a new pair RDD. The `reduceByKey()` transformation gathers together pairs that have the same key and applies the function provided to two values at a time, iteratively reducing all of the values to a single value. `reduceByKey()` operates by applying the function first within each partition on a per-key basis and then across the partitions, allowing it to scale efficiently to large datasets.

// %%
// TODO: Replace ??? with appropriate code
// Note that reduceByKey takes in a function that accepts two values and returns a single value
val wordCounts = wordPairs.reduceByKey(_ + _)
wordCounts.collect.foreach(println)
// Out:
// (rat,2)
// (elephant,1)
// (cat,2)
// wordCounts = ShuffledRDD[18] at reduceByKey at <console>:32
// ShuffledRDD[18] at reduceByKey at <console>:32

// %%
// TEST Counting using reduceByKey (2c)
assertResult(List(("cat", 2), ("elephant", 1), ("rat", 2)),
  "incorrect value for wordCounts") {
  wordCounts.collect.sortBy(_._1).toList
}
// Out:
// 1 test passed

// %% [markdown]
// ### (2d) All together
//
// The expert version of the code performs the `map()` to pair RDD, `reduceByKey()` transformation, and `collect` in one statement.

// %%
// TODO: Replace ??? with appropriate code
val wordCountsCollected = wordsRDD
                          .map(w => w -> 1)
                          .reduceByKey(_ + _)
  .collect()
wordCountsCollected.foreach(println)
// Out:
// (rat,2)
// (elephant,1)
// (cat,2)
// wordCountsCollected = Array((rat,2), (elephant,1), (cat,2))
// Array((rat,2), (elephant,1), (cat,2))

// %%
// TEST All together (2d)
assertResult(List(("cat", 2), ("elephant", 1), ("rat", 2)),
"incorrect value for wordCountsCollected") {
  wordCountsCollected.sortBy(_._1).toList
}
// Out:
// 1 test passed

// %% [markdown]
// ##  3. Finding unique words and a mean value

// %% [markdown]
// ### (3a) Unique words
//
// Calculate the number of unique words in `wordsRDD`.  You can use other RDDs that you have already created to make this easier.

// %%
// TODO: Replace ??? with appropriate code
val uniqueWords = wordsRDD
  .map(w => w -> 1)
  .groupByKey()
  .count
println(uniqueWords)
// Out:
// 3
// uniqueWords = 3
// 3

// %%
// TEST Unique words (3a)
assertResult(3, "incorrect count of uniqueWords") {
  uniqueWords.toInt
}
// Out:
// 1 test passed

// %% [markdown]
// ### (3b) Mean using `reduce`
//
// <p>Find the mean number of words per unique word in `wordCounts`.<br/>
//
// Use a `reduce()` action to sum the counts in `wordCounts` and then divide by the number of unique words.  First `map()` the pair RDD `wordCounts`, which consists of (key, value) pairs, to an RDD of values.</p>

// %%
// TODO: Replace ??? with appropriate code
import scala.math.BigDecimal.RoundingMode
val totalCount = (wordCounts
  .map(_._2)
//  .reduce(_ + _)
  .reduce { case (s, occ) => s + occ }
                 )
val average = totalCount / uniqueWords.toFloat
println(totalCount)
println(BigDecimal(average).setScale(2, RoundingMode.HALF_UP))
// Out:
// 5
// 1.67
// totalCount = 5
// average = 1.6666666
// warning: there was one deprecation warning; re-run with -deprecation for details
// 1.6666666

// %%
// TEST Mean using reduce (3b)
assertResult( BigDecimal(1.67), "incorrect value of average") {
  BigDecimal(average).setScale(2, RoundingMode.HALF_UP)
}
// Out:
// warning: there was one deprecation warning; re-run with -deprecation for details
// 1 test passed

// %% [markdown]
// ## 4.  Apply word count to a file

// %% [markdown]
// In this section we will finish developing our word count application.  We'll have to build the `wordCount` function, deal with real world problems like capitalization and punctuation, load in our data source, and compute the word count on the new data.

// %% [markdown]
// ### (4a) `wordCount` function
//
// First, define a function for word counting.  You should reuse the techniques that have been covered in earlier parts of this lab.  This function should take in an RDD that is a list of words like `wordsRDD` and return a pair RDD that has all of the words and their associated counts.

// %%
// TODO: Replace <FILL IN> with appropriate code
import org.apache.spark.rdd.RDD
def wordCount(wordListRDD: RDD[String]) : RDD[(String,Int)] = {
  /*Creates a pair RDD with word counts from an RDD of words.
  Args:
  wordListRDD (RDD of str): An RDD consisting of words.
  Returns:
  RDD of (str, int): An RDD consisting of (word, count) tuples.
  */
  wordListRDD.map(_ -> 1).reduceByKey(_ + _)
}
wordCount(wordsRDD).collect.foreach(println)
// Out:
// wordCount: (wordListRDD: org.apache.spark.rdd.RDD[String])org.apache.spark.rdd.RDD[(String, Int)]
// (rat,2)
// (elephant,1)
// (cat,2)

// %%
// TEST wordCount function (4a)
assertResult(List(("cat", 2), ("elephant", 1), ("rat", 2)),
"incorrect definition for wordCount function") {
  wordCount(wordsRDD).collect.sortBy(_._1).toList
}
// Out:
// 1 test passed

// %% [markdown]
// ### (4b) Capitalization and punctuation
//
// Real world files are more complicated than the data we have been using in this lab. Some of the issues we have to address are:
//
//   +  Words should be counted independent of their capitialization (e.g., Spark and spark should be counted as the same word).
//   +  All punctuation should be removed.
//   +  Any leading or trailing spaces on a line should be removed.
//
// Define the function `removePunctuation` that converts all text to lower case, removes any punctuation, and removes leading and trailing spaces.  Use `replaceAll` to remove any text that is not a letter, number, or space.

// %%
// TODO: Replace <FILL IN> with appropriate code
val removePunctuation = (text:String) => {
  /*
Removes punctuation, changes to lower case, and strips leading and trailing spaces.
Note:
    Only spaces, letters, and numbers should be retained.  Other characters should should be
    eliminated (e.g. it's becomes its).  Leading and trailing spaces should be removed after
    punctuation is removed.
Args:
    text (str): A string.
Returns:
    str: The cleaned up string.
   */
  val text_no_punctuation = text.replaceAll("[^a-zA-Z0-9 ]+","")
  text_no_punctuation.trim.toLowerCase
}
println(removePunctuation("Hi, you!"))
println(removePunctuation(" No under_score!"))
// Out:
// hi you
// no underscore
// removePunctuation = > String = <function1>
// > String = <function1>

// %%
assertResult("the elephants 4 cats",
  "incorrect definition for removePunctuation function") {
  removePunctuation(" The Elephant's 4 cats. ")
}
// Out:
// 1 test passed

// %% [markdown]
// ### (4c) Load a text file
//
// For the next part of this lab, we will use the [Complete Works of William Shakespeare](http://www.gutenberg.org/ebooks/100) from [Project Gutenberg](http://www.gutenberg.org/wiki/Main_Page). To convert a text file into an RDD, we use the `SparkContext.textFile()` method. We also apply the recently defined `removePunctuation()` function using a `map()` transformation to strip out the punctuation and change all text to lowercase.  Since the file is large we use `take(15)`, so that we only print 15 lines.

// %%
// Just run this code
val fileName = "../data/shakespeare.txt"
val shakespeareRDD = (sc
  .textFile(fileName, 8)
  .map(removePunctuation))
shakespeareRDD
  .zipWithIndex()  // to (line, lineNum)
  .map(x => s"${x._2}:${x._1}")  // to 'lineNum: line'
.take(15).foreach(println)
// Out:
// 0:1609
// 1:
// 2:the sonnets
// 3:
// 4:by william shakespeare
// 5:
// 6:
// 7:
// 8:1
// 9:from fairest creatures we desire increase
// 10:that thereby beautys rose might never die
// 11:but as the riper should by time decease
// 12:his tender heir might bear his memory
// 13:but thou contracted to thine own bright eyes
// 14:feedst thy lights flame with selfsubstantial fuel
// fileName = ../data/shakespeare.txt
// shakespeareRDD = MapPartitionsRDD[31] at map at <console>:38
// MapPartitionsRDD[31] at map at <console>:38

// %% [markdown]
// ### (4d) Words from lines
//
// Before we can use the `wordcount()` function, we have to address two issues with the format of the RDD:
//
//   +  The first issue is that  that we need to split each line by its spaces.
//   +  The second issue is we need to filter out empty lines.
//
// Apply a transformation that will split each element of the RDD by its spaces. For each element of the RDD, you should apply the string [split()](https://docs.oracle.com/javase/8/docs/api/java/lang/String.html#split-java.lang.String-) function. You might think that a `map()` transformation is the way to do this, but think about what the result of the `split()` function will be. Use an other transformation.

// %%
// TODO: Replace ??? with appropriate code
val shakespeareWordsRDD: RDD[String] = shakespeareRDD.flatMap(_.split(" "))
val shakespeareWordCount = shakespeareWordsRDD.count
shakespeareWordsRDD.top(5).foreach(println)
println(shakespeareWordCount)
// Out:
// zwaggerd
// zounds
// zounds
// zounds
// zounds
// 927631
// shakespeareWordsRDD = MapPartitionsRDD[84] at flatMap at <console>:36
// shakespeareWordCount = 927631
// 927631

// %%
// TEST Words from lines (4d)
// This test allows for leading spaces to be removed either before or after punctuation is removed.
assertResult(true, "incorrect value for shakespeareWordCount") {
  shakespeareWordCount == 927631 || shakespeareWordCount == 928908
}
// Out:
// 1 test passed

// %% [markdown]
// ### (4e) Remove empty elements
//
// The next step is to filter out the empty elements.  Remove all entries where the word is `''`.

// %%
// TODO: Replace ??? with appropriate code
val shakeWordsRDD = shakespeareWordsRDD.filter(!_.isEmpty)
val shakeWordCount = shakeWordsRDD.count
println(shakeWordCount)
// Out:
// 882996
// shakeWordsRDD = MapPartitionsRDD[86] at filter at <console>:36
// shakeWordCount = 882996
// 882996

// %%
// TEST Remove empty elements (4e)
assertResult(882996 , "incorrect value for shakeWordCount") {
  shakeWordCount.toInt
}
// Out:
// 1 test passed

// %% [markdown]
// ### (4f) Count the vocabulary size
//
// How many different words (vocabulary size) are there in Shakespeare's vocabulary?

// %%
// let us get the complete Shakespare' vocabulary
val shakespare_vocab_size = wordCount(shakespeareWordsRDD.filter(!_.isEmpty)).count
println(s"Shakespeare vocabulary contains $shakespare_vocab_size words")
// Out:
// Shakespeare vocabulary contains 28147 words
// shakespare_vocab_size = 28147
// 28147

// %%
// TEST Count the vocabulary size (4f)
assertResult(28147, "incorrect value for shakespare_vocab_size") {
 shakespare_vocab_size.toInt
}
// Out:
// 1 test passed

// %% [markdown]
// (4g) Get the top words
//
// We now have an RDD that is only words.  Next, let's apply the `wordCount()` function to produce a list of word counts. We can view the top 15 words by using the `takeOrdered()` action; however, since the elements of the RDD are pairs, we need a custom sort function that sorts using the value part of the pair.
//
// <p>You'll notice that many of the words are common English words. These are called stopwords. In a later lab, we will see how to eliminate them from the results.<br/>
// Use the `wordCount()` function and `takeOrdered()` to obtain the fifteen most common words and their counts.</p>

// %%
// TODO Replace ??? with appropriate code
val top15WordsAndCounts = wordCount(shakespeareWordsRDD).filter(!_._1.isEmpty).sortBy(-_._2).take(15)
top15WordsAndCounts.foreach(x => println(s"${x._1}: ${x._2}"))
// Out:
// the: 27361
// and: 26028
// i: 20681
// to: 19150
// of: 17463
// a: 14593
// you: 13615
// my: 12481
// in: 10956
// that: 10890
// is: 9134
// not: 8497
// with: 7771
// me: 7769
// it: 7678
// top15WordsAndCounts = Array((the,27361), (and,26028), (i,20681), (to,19150), (of,17463), (a,14593), (you,13615), (my,12481), (in,10956), (that,10890), (is,9134), (not,8497), (with,7771), (me,7769), (it,7678))
// Array((the,27361), (and,26028), (i,20681), (to,19150), (of,17463), (a,14593), (you,13615), (my,12481), (in,10956), (that,10890), (is,9134), (not,8497), (with,7771), (me,7769), (it,7678))

// %%
// TEST Count the words (4f)
assertResult(
  List(("the", 27361), ("and", 26028), ("i", 20681), ("to", 19150), ("of", 17463),
("a", 14593), ("you", 13615), ("my", 12481), ("in", 10956), ("that", 10890),
("is", 9134), ("not", 8497), ("with", 7771), ("me", 7769), ("it", 7678)),
"incorrect value for top15WordsAndCounts") {
  top15WordsAndCounts.toList
}
// Out:
// 1 test passed

// %% [markdown]
// # Part 2 : Short tutorial to DataFrames
//
// and chaining together transformations and actions
//
// ## 1. Working with your first DataFrames
//
// In Spark, we first create a base [DataFrame](http://spark.apache.org/docs/latest/api/scala/index.html#org.apache.spark.sql.package@DataFrame=org.apache.spark.sql.Dataset[org.apache.spark.sql.Row]). We can then apply one or more transformations to that base DataFrame. *A DataFrame is immutable, so once it is created, it cannot be changed.* As a result, each transformation creates a new DataFrame. Finally, we can apply one or more actions to the DataFrames.
//
// > Note that Spark uses lazy evaluation, so transformations are not actually executed until an action occurs.
//
// We will perform several exercises to obtain a better understanding of DataFrames:
// * Create a collection of 10,000 people
// * Create a Spark DataFrame from that collection
// * Subtract one from each value using `map`
// * Perform action `collect` to view results
// * Perform action `count` to view counts
// * Apply transformation `filter` and view results with `collect`
// * Learn about lambda functions
// * Explore how lazy evaluation works and the debugging challenges that it introduces
//
// A DataFrame consists of a series of `Row` objects; each `Row` object has a set of named columns. You can think of a DataFrame as modeling a table, though the data source being processed does not have to be a table.
//
// More formally, a DataFrame must have a _schema_, which means it must consist of columns, each of which has a _name_ and a _type_. Some data sources have schemas built into them. Examples include RDBMS databases, Parquet files, and NoSQL databases like Cassandra. Other data sources don't have computer-readable schemas, but you can often apply a schema programmatically.

// %% [markdown]
// ## 2. Create a collection of 10,000 people
//
// Normally in this section we would use a third-party Scala library to create a collection of fake person records. Since the import doesn't work well in the Scala version of the notebook, we will load a .csv file containing the records previously and ramdomly generated from the python version of the notebook

// %% [markdown]
// We're going to load a collection of randomly generated people records.
// In the next section, we'll turn that collection into a DataFrame.
// We'll use the `spark.implicits._`, because that will give us helpers to create a DataFrame from a List for example.
// There are other ways to define schemas, though; see
// the Spark Programming Guide's discussion of [schema inference](http://spark.apache.org/docs/latest/sql-programming-guide.html#inferring-the-schema-using-reflection) for more information. (In here, we can directly create a dataframe from reading the csv file, but for the purpose of this section we will create a dataframe from a RDD)

// %%
import spark.implicits._
val dataRDD = sc.textFile("../data/10000persons.csv")
  .map(_.split(";"))
  .map(x => (x(0),x(1),x(2),x(3),x(4).toInt))
// Out:
// dataRDD = MapPartitionsRDD[208] at map at <console>:45
// MapPartitionsRDD[208] at map at <console>:45

// %% [markdown]
// ## 3. Distributed data and using a collection to create a DataFrame
//
// In Spark, datasets are represented as a list of entries, where the list is broken up into many different partitions that are each stored on a different machine.  Each partition holds a unique subset of the entries in the list.  Spark calls datasets that it stores "Resilient Distributed Datasets" (RDDs). Even DataFrames are ultimately represented as RDDs, with additional meta-data.
//
// <img src="http://spark-mooc.github.io/web-assets/images/cs105x/diagram-3b.png" style="width: 900px; float: right; margin: 5px"/>
//
// One of the defining features of Spark, compared to other data analytics frameworks (e.g., Hadoop), is that it stores data in memory rather than on disk.  This allows Spark applications to run much more quickly, because they are not slowed down by needing to read data from disk.
// The figure to the right illustrates how Spark breaks a list of data entries into partitions that are each stored in memory on a worker.
//
//
// To create the DataFrame, we'll use `sqlContext.createDataFrame()`, and we'll pass our array of data in as an argument to that function. Spark will create a new set of input data based on data that is passed in.  A DataFrame requires a _schema_, which is a list of columns, where each column has a name and a type. Our list of data has elements with types (mostly strings, but one integer). We'll supply the rest of the schema and the column names as the argument to `toDF`.

// %%
val dataDF = dataRDD.toDF("last_name", "first_name", "ssn", "occupation", "age")
// Out:
// dataDF = [last_name: string, first_name: string ... 3 more fields]
// [last_name: string, first_name: string ... 3 more fields]

// %% [markdown]
// Let's take a look at the DataFrame's schema and some of its rows.

// %%
dataDF.printSchema()
// Out:
// root
//  |-- last_name: string (nullable = true)
//  |-- first_name: string (nullable = true)
//  |-- ssn: string (nullable = true)
//  |-- occupation: string (nullable = true)
//  |-- age: integer (nullable = false)

// %% [markdown]
// How many partitions will the DataFrame be split into?

// %%
dataDF.rdd.getNumPartitions
// Out:
// 2

// %% [markdown]
// ## 4. Subtract one from each value using _select_
//
// So far, we've created a distributed DataFrame that is splitted into many partitions, where each partition is stored on a single machine in our cluster.  Let's look at what happens when we do a basic operation on the dataset.  Many useful data analysis operations can be specified as "do something to each item in the dataset".  These data-parallel operations are convenient because each item in the dataset can be processed individually: the operation on one entry doesn't effect the operations on any of the other entries.  Therefore, Spark can parallelize the operation.
//
// One of the most common DataFrame operations is `select()`, and it works more or less like a SQL `SELECT` statement: You can select specific columns from the DataFrame, and you can even use `select()` to create _new_ columns with values that are derived from existing column values. We can use `select()` to create a new column that decrements the value of the existing `age` column.
//
// `select()` is a _transformation_. It returns a new DataFrame that captures both the previous DataFrame and the operation to add to the query (`select`, in this case). But it does *not* actually execute anything on the cluster. When transforming DataFrames, we are building up a _query plan_. That query plan will be optimized, implemented (in terms of RDDs), and executed by Spark _only_ when we call an action (see Lazy Evaluation process).

// %%
// Transform dataDF through a select transformation and rename the newly created '(age -1)' column to 'age'
// Because select is a transformation and Spark uses lazy evaluation, no jobs, stages, or tasks will be launched when we run this code.
val subDF = dataDF
  .select(
      dataDF("last_name"),
      dataDF("first_name"),
      dataDF("ssn"),
      dataDF("occupation"),
      (dataDF("age") - 1).alias("age")
)
// Out:
// subDF = [last_name: string, first_name: string ... 3 more fields]
// [last_name: string, first_name: string ... 3 more fields]

// %%
%%dataframe --limit=50
subDF//.show(truncate=false)
// Out:
// <table><tr><th>last_name</th><th>first_name</th><th>ssn</th><th>occupation</th><th>age</th></tr><tr><td>Ruiz</td><td>Michelle</td><td>561-47-8114</td><td>Agent de transit</td><td>33</td></tr><tr><td>Lebreton</td><td>Alex</td><td>658-13-3841</td><td>Architecte produit industriel</td><td>6</td></tr><tr><td>Lombard</td><td>Sophie</td><td>981-29-0464</td><td>Chercheur en biologie</td><td>37</td></tr><tr><td>Bonnin</td><td>Élise</td><td>035-58-3904</td><td>Encadreur</td><td>29</td></tr><tr><td>Valentin</td><td>Tristan</td><td>358-19-7650</td><td>Mécatronicien</td><td>37</td></tr><tr><td>de</td><td>Margaud</td><td>143-41-2672</td><td>Ingénieur chimiste en développement analytique</td><td>1</td></tr><tr><td>Mercier</td><td>Martine-Thérèse</td><td>938-12-8151</td><td>Officier de la marine marchande</td><td>11</td></tr><tr><td>Peron</td><td>Antoine</td><td>385-65-0441</td><td>Directeur de création</td><td>35</td></tr><tr><td>Chartier</td><td>Lucas</td><td>356-40-3015</td><td>Électromécanicien</td><
// %% [markdown]
// ##  5.  Use _collect_ or _show_ to view results
//
// <img src="http://spark-mooc.github.io/web-assets/images/cs105x/diagram-3d.png" style="height:700px;float:right"/>
//
// To see a list of elements decremented by one, we need to create a new list on the driver from the the data distributed in the executor nodes.  To do this we can call the `collect()` method on our DataFrame.  `collect()` is often used after transformations to ensure that we are only returning a *small* amount of data to the driver.  This is done because the data returned to the driver must fit into the driver's available memory.  If not, the driver will crash.
//
// The `collect()` method is the first action operation that we have encountered.  Action operations cause Spark to perform the (lazy) transformation operations that are required to compute the values returned by the action.  In our example, this means that tasks will now be launched to perform the `toDF`, `select`, and `collect` operations.
//
// In the diagram, the dataset is broken into four partitions, so four `collect()` tasks are launched. Each task collects the entries in its partition and sends the result to the driver, which creates a list of the values, as shown in the figure below.
//
// Now let's run `collect()` on `subDF`.

// %%
subDF.take(3)
// Out:
// Array([Ruiz,Michelle,561-47-8114,Agent de transit,33], [Lebreton,Alex,658-13-3841,Architecte produit industriel,6], [Lombard,Sophie,981-29-0464,Chercheur en biologie,37])

// %%
// Let's collect the data
val results = subDF.collect()
results.foreach(println)
// Out:
// [Ruiz,Michelle,561-47-8114,Agent de transit,33]
// [Lebreton,Alex,658-13-3841,Architecte produit industriel,6]
// [Lombard,Sophie,981-29-0464,Chercheur en biologie,37]
// [Bonnin,Élise,035-58-3904,Encadreur,29]
// [Valentin,Tristan,358-19-7650,Mécatronicien,37]
// [de,Margaud,143-41-2672,Ingénieur chimiste en développement analytique,1]
// [Mercier,Martine-Thérèse,938-12-8151,Officier de la marine marchande,11]
// [Peron,Antoine,385-65-0441,Directeur de création,35]
// [Chartier,Lucas,356-40-3015,Électromécanicien,34]
// [Marchand,Émilie,427-32-8671,Assistant,1]
// [Loiseau,Christophe,987-30-8626,Chercheur en physique,2]
// [Fabre-Marin,Thérèse,175-24-9412,Ingénieur process aval,15]
// [Laine,Théophile,412-10-7314,Ingénieur réservoir,46]
// [Blanchard,Odette,893-14-5482,Optronicien,7]
// [Bertrand,Gilles-Yves,365-88-5286,Développeur économique,18]
// [Gerard,Caroline,998-15-9514,Commerçant en alimentation,26]
// [Gauthier,Alexandre,287-63-1470,Opérateur de raffinerie,42]
// [Allain,Aurore,530-04-7920,Maître-chien,30]
// [Faure,Corinne,212-77-1369,Vendeur en animalerie,32]
// [Texier,David,096-41-2299,Responsable de formation,2]
// [Roussel,Dominique,716-67-2870,Responsable de la promotion des ventes,16]
// [Le,Suzanne,774-31-8272,Agent artistique,20]
// [Henry-Da,Éléonore,344-53-2547,Ingénieur en construction navale,29]
// [Fernandes,Aurélie,006-81-0101,Encadreur,2]
// [Gilles,Alexandria,446-42-9242,Chargé,10]
// [Le,Françoise,300-88-4997,Souscripteur,45]
// [Le,Yves,207-48-3411,Céramiste,44]
// [Gerard,Olivier,382-73-4650,Ingénieur télécoms et réseaux,12]
// [Blanc,Véronique,135-14-0051,Enseignant d'art,30]
// [Joly,Hélène,576-67-3338,Salesman,27]
// [Lamy,Gilles,813-72-7015,Administrateur de spectacle,8]
// [Chauvin,Guy,359-38-4354,Responsable de projets culturels,23]
// [Petitjean,Emmanuel,310-32-2334,Hydrologue,1]
// [Guilbert,Élise,392-99-9718,Agent de propreté et d'hygiène,7]
// [Lebreton,Zacharie,670-27-8795,Juge d'instruction,4]
// [Georges,Julie,251-65-3432,Expert en sécurité informatique,44]
// [Peron-Pereira,Eugène,451-82-8423,Intégrateur web,24]
// [Dufour,Noël,201-27-0404,Paléontologue,24]
// [Devaux,Aimée,597-32-3414,Professeur documentaliste,5]
// [de,Pierre,936-65-8972,Lad-jockey, lad-driver,15]
// [de,Tristan,960-86-1236,Maître nageur sauveteur,22]
// [Gaudin,Patrick,520-65-1675,Responsable du service après-vente,21]
// [Breton-Fleury,Adélaïde,147-19-6098,Contrôleur de gestion,8]
// [Hoareau,Geneviève-Diane,351-05-7627,Chercheur en physique,0]
// [Moreau,Julien,846-71-1245,Chargé d'études naturalistes,36]
// [Le,Emmanuelle,515-59-7421,Horticulteur,36]
// [Pottier,Océane,990-03-6033,Designer d'interaction,18]
// [Laine,Gilbert,323-06-4120,Ingénieur production en mécanique,25]
// [Dupre,Luce,678-22-5204,Technicien de maintenance en génie climatique,16]
// [Foucher,Madeleine,403-90-8671,Gestionnaire de données cliniques,6]
// [Labbe,Cécile,706-66-6942,Juriste en propriété intellectuelle,32]
// [Gosselin,Juliette,301-21-3794,Viticulteur,35]
// [de,Philippe,539-31-7434,Neurobiologiste,45]
// [Seguin,Alphonse,747-35-0051,Couvreur,44]
// [Gomez,Théodore,978-61-1108,Manager de risques,36]
// [Dos,Thierry-Rémy,852-26-7257,Expert-comptable,43]
// [Olivier,Adèle,767-14-3250,Qualiticien,35]
// [Colin,Anaïs,003-63-8262,Cuisinier,34]
// [Barbier,Michèle,612-67-5450,Responsable de réseau eau potable,34]
// [Albert-Gauthier,Rémy,747-74-1615,Guide de haute montagne,36]
// [Noel,Tristan,284-80-4382,Ingénieur d'application,14]
// [Allard-Laine,Xavier,859-69-3822,Boucher,14]
// [Faivre,Louis,137-43-1035,Technicien,8]
// [Durand,Émile,634-33-2503,Technicien en traitement des déchets,4]
// [Gomez,Nicolas,469-38-7418,Acheteur,40]
// [Lebon,Isaac,825-63-3295,Dresseur d'animaux,36]
// [Charpentier,Aimée,424-92-6241,Directeur de création,46]
// [Jacquot,Thierry,200-36-8577,Employé de restaurant,18]
// [Boucher-Durand,Éléonore,438-33-5791,Technicien,38]
// [Torres-Morel,Océane,121-93-0093,Agent artistique,1]
// [Bouvier,Jacques,251-21-3482,Adjoint,33]
// [Joseph,François,507-92-0478,Scripte,27]
// [Guibert,Léon,274-54-2306,Éducateur de jeunes enfants,6]
// [Poirier,Marcel,682-10-1264,Géomètre-topographe,23]
// [De,Timothée-Gérard,904-27-5044,Responsable de réseau d'assainissement,40]
// [Dias,Margaux,322-12-5838,Ingénieur technico-commerciale en électronique,44]
// [Paris,Adrien,495-16-2925,Installateur en télécoms,45]
// [Gonzalez,Jeanne,881-21-6184,Professeur de musique et de danse,26]
// [Blin,Christophe,250-73-5900,Responsable de la rémunération,20]
// [Huet,Michel,913-60-8557,Collaborateur de notaire,8]
// [Becker-Vidal,Monique,255-86-8216,Technicien d'essais,1]
// [Gallet,Louis,273-74-2038,Ouvrier paysagiste,3]
// [Pineau,Nathalie,196-96-3626,Accompagnateur de voyages,14]
// [Thibault,Susanne,030-79-3969,Éducateur,41]
// [Blot,Roland,731-35-7407,Responsable de formation,30]
// [Lebon,Benjamin,461-95-9135,Vendeur en animalerie,28]
// [Rocher,Sophie,335-23-0763,Conducteur de scierie,35]
// [Le,Roger,559-79-1395,Conducteur,5]
// [Maillot-Fernandes,Anastasie,659-51-9616,Veilleur stratégique,43]
// [Lacroix,Yves,932-57-5257,Commercial export,15]
// [Sauvage,Guy,000-65-4439,Conducteur de scierie,45]
// [Renault,Anastasie,011-17-1856,Costumier,23]
// [Leblanc,Claire,751-44-8028,Ingénieur fluides, énergies, réseaux, environnement,16]
// [Renault,Bernard,491-84-2694,Bijoutier,8]
// [Perrin,Nathalie,590-72-8188,Cordonnier,41]
// [Peron-Henry,Diane,244-12-0621,Ingénieur d'application,40]
// [du,Josette,570-66-3495,Ethnologue,13]
// [Le,Franck,580-49-5196,Directeur d'office de tourisme,21]
// [Ferrand,Michelle,970-91-5930,Ingénieur en R et D en énergies renouvelables,3]
// [Joubert,Michelle,773-15-4955,Conseiller d'insertion et de probation,41]
// [Gomez,Sabine,146-41-1468,Contrôleur de gestion,40]
// [Leduc,Guy,641-34-6856,Biologiste médical,22]
// [Brun,Éléonore,579-82-8243,Architecte,10]
// [Pierre,Audrey,931-87-8017,Conseiller agricole,36]
// [Klein,Olivie,219-66-5597,Iconographe,37]
// [Monnier,Lucy,599-02-5714,Attaché de presse,6]
// [Riviere,Alain-Éric,910-58-0496,Éleveur,21]
// [Morel,Diane,526-14-9457,Hot liner,26]
// [Pruvost,Jérôme,691-28-9178,Gérant de restauration collective,13]
// [Duhamel,Maryse,717-11-5006,Cadreur,15]
// [Langlois,Josette,599-57-8564,Déclarant en douane,38]
// [Grenier,Brigitte,621-69-0272,Brodeur,14]
// [Gomez-Lemaire,Claudine,583-06-0804,Technicien nucléaire,25]
// [Delahaye,Benjamin,740-98-2981,Ingénieur en mécanique,13]
// [David,Grégoire,379-54-5579,Ingénieur du son,32]
// [Noel-Auger,Lucas,819-84-8471,Horticulteur,37]
// [Lecoq,Michèle,509-96-2079,Microtechnicien,41]
// [Perez,Roger,064-35-2458,Coiffeur,20]
// [Maurice,Catherine,898-97-4347,Secrétaire d'édition,37]
// [de,Jeanne,931-67-2295,Gestionnaire de portefeuille,4]
// [Rodrigues,Luc,250-76-1386,Pédiatre,40]
// [de,Aurélie,481-56-8344,Histologiste,30]
// [Charpentier,Charlotte,254-00-8064,Développeur humanitaire,44]
// [Ferrand,Margot,717-98-0293,Chef de projet sites et sols pollués,17]
// [Morvan,Bertrand,237-62-3923,Ingénieur textile,4]
// [Hamon,Martine-Véronique,885-32-5554,Conducteur de machines agricoles,1]
// [Chevallier,Margaud,527-25-2109,Psychomotricien,25]
// [Pons-Tessier,Georges,679-59-6011,Attaché de recherche clinique,3]
// [Menard,Aurélie,837-62-8796,Infirmier,24]
// [Neveu,Margaux,621-47-7200,Ingénieur systèmes embarqués,9]
// [Potier,Pierre,231-63-9943,Trader,5]
// [Marchal,Xavier,530-08-0443,Économe de flux,20]
// [du,Caroline,586-79-7538,Ingénieur du son,8]
// [Mallet,Hugues,061-06-3820,Couvreur,22]
// [Simon,Michèle,144-88-8707,Assistant,6]
// [Cordier-Dubois,Luc,060-96-5907,Éditeur,33]
// [Clement,Adèle,587-93-0520,Consultant,42]
// [Foucher-Boutin,François,027-55-5236,ingénieur,17]
// [du,Noémi,833-75-7290,Ingénieur hydroécologue,13]
// [Le,Alexandria,318-41-5756,Animateur nature,34]
// [Fernandez,Timothée,761-95-2432,Technicien de police technique et scientifique,11]
// [du,Émilie,052-70-5065,Consignataire de navire,43]
// [Weiss,Paul,599-28-8590,Cartographe,9]
// [Bouvet-Bouvet,Éric,351-50-6635,Matelot,38]
// [Gaillard,Martin,683-42-5860,Technico-commercial en agroalimentaire,32]
// [Foucher,Marcelle,535-91-7452,Régleur,29]
// [Foucher,Paul,786-46-4155,Tailleur,29]
// [Vidal,Gabriel,285-01-8059,Technicien nucléaire,2]
// [Le,Arnaude,394-89-0692,Céramiste,6]
// [de,Jeanne,895-96-0066,Éclairagiste,45]
// [Le,Colette,507-65-5200,Conducteur de machines à papier,6]
// [Lebreton,Thierry,940-65-9889,Facteur d'instruments,3]
// [de,Susan,695-32-2517,Attaché de recherche clinique,19]
// [Faure,Richard,308-87-9686,Architecte web,30]
// [Thierry,Thomas,623-69-6558,Météorologiste,45]
// [Ruiz,Claire,058-71-7200,Agent des méthodes,40]
// [Lelievre-Diallo,Raymond,468-10-5420,Hôte d'accueil,45]
// [Buisson,Thibaut,981-48-3614,Ambulancier,30]
// [Dumas,Georges,275-47-1149,Sérigraphe,28]
// [Rey-Robert,Audrey,255-02-0031,Biologiste médical,10]
// [de,Marguerite,207-78-1046,Biostatisticien,24]
// [Bernier-Diaz,Raymond,692-54-0699,Directeur de restaurant,1]
// [Da,Émile,019-34-2541,Lad-jockey, lad-driver,3]
// [Briand,Bernadette,456-39-8520,Gendarme,14]
// [Morel,Victoire,255-81-2440,Pharmacien dans l'industrie,42]
// [Coste,Denis,032-76-7332,Coordonnateur d'études cliniques,22]
// [Leleu-Evrard,Roland,778-49-3188,Chargé d'études en marketing,45]
// [Pereira,Jeannine,536-48-5915,Caviste,17]
// [Laporte-Charrier,Charles,479-13-5456,Clerc d'huissier,29]
// [Olivier,Margaud,138-40-7152,Technicien d'exploitation de l'eau,32]
// [Ferreira,Auguste,559-31-4944,Boulanger,9]
// [Etienne,Robert,133-57-6236,Chirurgien,22]
// [Fontaine,Timothée,509-17-4163,Attaché,43]
// [de,Aurélie,948-02-8099,Zoologiste,23]
// [Bonneau,Édith,657-59-1288,Accompagnateur de moyenne montagne,19]
// [Le,Mathilde,515-12-2725,Facteur d'instruments,11]
// [Tanguy,Daniel,613-82-1444,Collecteur de fonds,26]
// [Toussaint,Isabelle,387-82-7582,Mécanicien d'entretien d'avion,2]
// [Barbier,Louis,715-98-8467,Ingénieur technico-commercial en chimie,9]
// [Cohen,Anouk,775-61-6509,Responsable de la collecte des déchets ménagers,28]
// [Leveque-Gautier,Franck,789-16-9651,Modiste,22]
// [Dupuy,René,490-02-8808,Chercheur en biologie,12]
// [Le,Denis,625-41-8218,Magasinier cariste,28]
// [Roche,Eugène,430-02-8393,Manager de risques,27]
// [Guillaume,Benjamin,815-12-2239,Technicien automobile,9]
// [Guerin,Andrée,130-53-5126,Éclairagiste,19]
// [Perrot,Hugues,765-63-9605,Auxiliaire spécialisé vétérinaire,31]
// [Brunet-Jean,Denis,196-08-0590,Administrateur de logiciels de laboratoire,43]
// [Carlier-Aubert,Dorothée,169-91-9006,Avocat,28]
// [Guillou,Aurélie,690-15-8093,Scripte,28]
// [Guillot,Émile,441-96-2879,Infirmier,15]
// [Perez,Martine,182-93-2962,Expert-comptable,8]
// [Leroy,Aimée,665-09-5250,Bijoutier,0]
// [Coulon-Courtois,Anaïs,303-80-0109,Visiteur,32]
// [Brun,Victoire,421-55-8546,Chargé des méthodes outils et qualité en informatique,0]
// [Imbert-Toussaint,Zacharie,526-50-6272,Caissier,23]
// [Gerard,Daniel,699-60-6448,Chercheur en physique,24]
// [Bertin-Pires,Isabelle,485-31-5608,Accessoiriste,2]
// [Paris,Matthieu,378-58-8098,Auteur interprète,8]
// [Imbert,Honoré-Jean,960-98-7017,Ingénieur en production et expérimentations végétales,32]
// [Pasquier,Gérard,696-92-6269,Journaliste reporter d'images,24]
// [Maurice,Pierre,576-61-6888,Technicien d'exploitation du réseau gaz,10]
// [Le,Sylvie,994-07-0362,Ingénieur procédés en chimie,11]
// [Rolland,Aimé,371-47-1651,Bibliothécaire,9]
// [Clerc,Marthe,735-00-0190,Apiculteur,4]
// [Coste-Dias,Georges,412-30-8344,Chargé de communication interne,5]
// [Mallet,Lucas,896-65-4864,Électricien,39]
// [Ruiz,Benoît-Marc,531-64-8186,Technicien,15]
// [Begue,Antoine,303-15-4307,Responsable de laboratoire de contrôle en biologie,36]
// [du,Charles,884-58-5908,Attaché,35]
// [Le,Océane,051-49-7060,Commissaire de police,40]
// [Delorme,Raymond,415-67-0464,Technicien d'analyses biomédicales,11]
// [Andre,Isaac,186-36-5024,Ingénieur nucléaire,43]
// [Berthelot,Guillaume-Yves,576-48-2656,Employé de restaurant,22]
// [de,Olivier,948-24-3161,Ingénieur,1]
// [Godard,Édith-Simone,165-54-0655,Agent des méthodes,39]
// [Le,Benjamin,779-72-0132,Éducateur,46]
// [Moulin-Toussaint,Daniel,878-42-6075,Responsable assurance qualité,36]
// [Rossi,Aurélie,137-49-3815,Chargé d'affaires en génie mécanique,24]
// [Blondel,Marguerite,499-68-9335,Photographe,41]
// [Gonzalez,Denis,395-30-6273,Ingénieur en génie climatique,15]
// [Lecoq,Alix,525-00-7108,Éducateur,37]
// [Le,Alice,021-43-2130,Technicien céramiste,28]
// [Marie,Michèle,384-98-7324,Expert-comptable,21]
// [Benoit,Olivie,653-63-5029,Reporter-photographe,7]
// [Le,Isaac,268-46-2390,Conducteur de machines à papier,39]
// [Le,Victoire,262-88-4285,Modéliste,3]
// [Leleu,Emmanuelle,160-21-3251,Enseignant,26]
// [Schmitt,Olivier,661-34-6242,Contrôleur,16]
// [Gautier,Maurice,338-33-2504,Mécanicien,8]
// [Renard,Clémence-Simone,884-13-6985,Acheteur d'espaces publicitaires,30]
// [Couturier,Maryse,498-85-4654,Directeur d'hôtel,10]
// [Lefebvre-Leduc,Sophie,548-20-6911,Bottier,13]
// [Cohen,Lucy,181-91-7570,Biologiste en environnement,19]
// [Peron,Élodie,949-29-7080,Logisticien,6]
// [Boyer,Astrid,597-11-3862,Brodeur,36]
// [Duval,Danielle,444-46-5852,Cuisinier,9]
// [Weber,Christophe,013-26-1730,Solier-moquettiste,7]
// [Lemaire,Maurice,165-75-6722,Géographe,23]
// [Bonnin,Frédéric,773-04-7213,Technicien de maintenance en informatique,33]
// [Durand,Noël,883-06-7786,Chef de produit marketing,12]
// [Bruneau,Agathe,899-78-7636,Chargé d'études en valorisation agricole des déchets,23]
// [Guyot,Zacharie,164-62-3023,Conseiller agricole,32]
// [Munoz,Clémence,663-49-3053,Marchandiseur,22]
// [Laurent,Martin-Guy,551-05-0953,Apiculteur,44]
// [Paul,Thérèse-Dorothée,427-62-5281,Professeur dans l'enseignement agricole,44]
// [Blanc,Adrien,755-61-3988,Rédacteur en chef,3]
// [Perrot,Éric,951-96-0030,Juriste d'entreprise,5]
// [Lambert,Julie,468-73-0159,Assistant,35]
// [Sanchez,Victor,440-46-0025,Architecte naval,3]
// [Guibert,Lucy,528-74-6084,Conseiller d'éducation,42]
// [Petitjean,Vincent,195-71-5532,Conducteur de machines à papier,2]
// [Torres,Françoise,824-92-5321,Comédien,12]
// [du,Léon,345-93-5752,Conseiller en salle de remise en forme,41]
// [Roger,Théodore,452-88-0102,Commerçant en alimentation,22]
// [Petit,Alix,157-65-0546,Menuisier,2]
// [Laporte,Odette,194-91-5830,Technicien,12]
// [Joseph-Joly,Éléonore,769-01-6378,Visiteur,34]
// [Benard,Benjamin,357-20-5672,Oenologue,10]
// [Renard,Franck,246-93-2633,Médecin généraliste,6]
// [Gosselin,Michelle,718-23-9251,Comptable,11]
// [Leveque,Dominique,134-75-2738,Responsable qualité en agroalimentaire,18]
// [Lemoine-Henry,Timothée,988-84-1618,Mandataire judiciaire,10]
// [Merle,Simone,288-70-0938,Assistant,9]
// [Ruiz,Timothée,571-83-7107,Modéliste,31]
// [Allain,Josette,919-85-7623,Officier de la marine marchande,44]
// [Sanchez,Valérie,965-36-2080,Boucher,2]
// [Dupuis,Astrid-Juliette,096-88-6020,Animalier de laboratoire,4]
// [Dupuy,Claude,128-44-0140,Architecte réseau,21]
// [Gaillard,Tristan,074-55-9909,Responsable micro,7]
// [Hoareau,Luce,993-12-5973,Agent des méthodes,44]
// [Blin-Maillard,Alain,651-50-8288,Chef de produit marketing,18]
// [Mercier,Thérèse,252-46-9661,Chef de cultures légumières,18]
// [Chauveau,Richard-Sébastien,082-92-3507,Ingénieur,7]
// [Moulin,Adrienne,352-67-0975,Dessinateur de BD,44]
// [Millet,Aimée,597-30-8483,Étalagiste,35]
// [Maillot,Alix-Margot,985-24-8499,Accompagnateur de voyages,31]
// [Le,Margot,764-77-5688,Employé de pressing,37]
// [Poirier,Lucas,864-64-8404,Danseur,22]
// [Grondin,René,722-08-8788,Carreleur-mosaïste,29]
// [Bouchet,Richard-Benoît,288-95-5947,Masseur-kinésithérapeute,33]
// [Bazin,Aurore,239-53-6947,Directeur,13]
// [Weber-Reynaud,Léon,926-43-8920,Installateur en télécoms,22]
// [du,Grégoire,860-96-5812,Spécialiste des affaires réglementaires en chimie,39]
// [de,Camille,198-27-6806,Cordiste,32]
// [Le,Adrienne,194-74-9205,Opérateur de raffinerie,43]
// [Lenoir,Tristan,500-53-0134,Agent des méthodes,32]
// [Etienne,Thibault,014-44-9589,Danseur,10]
// [Roy-Nicolas,William,977-14-9773,Régisseur cinéma,26]
// [Labbe-Didier,Claude,725-80-7753,Chercheur en biologie,21]
// [Aubert-Aubert,Caroline,864-44-2854,Salesman,35]
// [Albert-Blanchet,René,334-71-7138,Ingénieur procédés en chimie,26]
// [Girard,Thierry,545-25-7328,Technicien des industries du verre,23]
// [Teixeira-De,Victor,778-48-5697,Hôte d'accueil,21]
// [Philippe,Pierre,411-09-8213,Médecin humanitaire,31]
// [Simon,Gabriel,023-40-8065,Technicien de police technique et scientifique,8]
// [Cordier,Éléonore,043-07-5229,Logisticien,3]
// [Guyon,Joseph,305-65-2905,Musicien,44]
// [Le,Marguerite,288-56-5448,Huissier de justice,3]
// [Grenier,Tristan,002-08-5739,Secrétaire d'édition,2]
// [Devaux,Théodore,378-24-2614,Testeur en informatique,44]
// [Dumont,Claude,324-26-7965,Responsable biométrie,26]
// [Roussel,Audrey,791-61-0963,Contrôleur,36]
// [Munoz,Pierre-Jules,473-41-0525,Technicien automobile,30]
// [Lopes,Françoise,250-51-6451,Intégrateur web,17]
// [Caron,Luce,861-18-7205,Chef de mission humanitaire,7]
// [Lebon,Astrid,890-93-4783,Ingénieur recherche et développement en agroalimentaire,2]
// [de,Thierry,448-97-3877,Technicien en traitement des déchets,15]
// [Riviere,Inès,894-09-9880,Responsable micro,40]
// [Marchal,Marie,232-24-8330,Bactériologiste,27]
// [Voisin,Sabine,377-14-1453,Chargé d'études en aménagement,40]
// [Dupuy,Élise,840-85-5499,Responsable de formation,33]
// [Lenoir,Jean,593-36-9445,Chargé de veille législative et réglementaire,39]
// [Vaillant-Noel,Chantal,930-78-4028,Commerçant en alimentation,27]
// [Lelievre,Pierre,357-42-2971,Responsable micro,4]
// [Pascal,Cécile,826-01-4981,Employé de restaurant,11]
// [Richard,Guillaume,656-61-3083,Économiste de la construction,2]
// [Martel,Martin,562-70-3722,Développeur informatique,43]
// [Faivre,Benoît,027-21-2555,Employé de pressing,7]
// [Loiseau,Manon,992-39-4822,Mixeur,25]
// [Coulon,Michelle,930-46-9707,Technicien d'analyses biomédicales,31]
// [de,Richard,408-26-4667,Cuisinier,19]
// [Renaud,Corinne,826-92-4243,Agent d'assurances,10]
// [Perret-Maillet,William,875-06-9461,Électromécanicien,43]
// [Fleury-Pascal,Tristan,749-23-4305,Secrétaire médical,46]
// [Couturier-Colas,Auguste,093-88-0880,Pilote de ligne,7]
// [Godard,Céline,616-21-1340,Opérateur prépresse,43]
// [Guillou-Dumont,Susanne,303-80-2208,Garde,35]
// [Collet,Raymond-Lucas,137-51-1247,Responsable de scierie,27]
// [Bazin,Constance,166-41-1075,Conseiller en salle de remise en forme,45]
// [Gautier,Paulette,467-50-2176,Plâtrier,33]
// [de,Tristan,064-63-5874,Conseiller en environnement,43]
// [Pires,Isaac,747-41-3398,Officier de police,19]
// [Carre,Michel,739-58-6558,Actuaire,19]
// [Samson,Sébastien,315-93-1738,Biostatisticien,41]
// [Loiseau,Alfred-Victor,144-39-6348,Enseignant de la conduite automobile et de la sécurité routière,1]
// [Dupuy,Margot,098-83-5956,Chirurgien,18]
// [Alexandre,Frédérique,818-07-5518,Responsable qualité en agroalimentaire,46]
// [Hardy,Aimé,937-06-9092,Formateur en informatique,3]
// [Bonnin,Hortense,391-10-0667,Géotechnicien,46]
// [Weiss,Élise,237-19-6854,Technicien biologiste,30]
// [Rossi,Bernard,315-22-8843,Agent de la surveillance SNCF,33]
// [Bourdon,Élise-Dorothée,401-38-2597,Technicien d'analyses biomédicales,12]
// [Albert,Véronique-Manon,741-41-1106,Ingénieur brevets,10]
// [Dumas-Duval,Bernard,341-03-9919,Credit manager,28]
// [Chartier,Guillaume,352-46-5572,Géomètre-topographe,19]
// [Arnaud,Luc-Guillaume,332-99-9638,Contrôleur de gestion,16]
// [Noel-Vallet,Frédérique,066-84-6691,Webdesigner,4]
// [Petitjean,Corinne,863-99-2954,Responsable des ressources humaines,5]
// [Noel,Timothée,409-11-4287,Marin pêcheur,33]
// [de,Arthur,032-35-5631,Formateur en informatique,4]
// [Auger,Margaud,671-40-4755,Directeur artistique,24]
// [Lenoir,Aurélie,816-95-3158,Chargé de référencement web,13]
// [Alves,Audrey,690-08-7965,Technicien de maintenance industrielle,17]
// [du,Pauline,054-91-1391,Astrophysicien,4]
// [Guyot,Virginie,007-13-1450,Technicien d'exploitation de l'eau,12]
// [du,Matthieu,693-59-2735,Consultant en validation,29]
// [Gros,Antoine-Gilbert,197-97-4066,Rédacteur on line,9]
// [de,Suzanne,564-18-1121,Horticulteur,17]
// [Navarro,Julien,530-70-4395,Technicien nucléaire,7]
// [Dupuis,Marine,968-54-8256,Pédiatre,24]
// [Lopez,Gilles,248-30-9084,Pédicure-podologue,21]
// [Delorme,Anouk,797-53-9971,Illustrateur,36]
// [Bodin,Zacharie,904-82-0858,Relieur,25]
// [Hubert,Paulette,970-50-0680,Animateur 2D et 3D,26]
// [Muller-Morin,Michèle,450-56-3229,Menuisier,20]
// [Maurice,Agnès,651-63-6186,Chargé des relations publiques,35]
// [du,Frédéric,086-50-0310,Géologue,2]
// [Delaunay,Joseph,001-98-9611,Conseiller en séjours,5]
// [Evrard,Valérie,781-39-5218,Géophysicien,28]
// [de,Louise,745-14-6334,Directeur d'hôtel,8]
// [Barthelemy,Lucas,776-04-9863,Conducteur de scierie,0]
// [de,Zoé,064-45-9045,Déclarant en douane,18]
// [du,David,109-53-7604,Inspecteur,9]
// [Gilles,Hugues,164-97-1281,Animateur 2D et 3D,2]
// [Valette-Blanchard,Capucine,696-92-7875,Scripte,43]
// [Roussel,Paul,630-32-9620,Officier de marine,40]
// [Marty,Danielle,705-75-7033,Ingénieur gaz,24]
// [Deschamps,François,349-50-7909,Charpentier métallique,35]
// [Vasseur,Alexandria,906-15-4010,Responsable de plate-forme biotechnologique,20]
// [Dufour,Sylvie,621-09-9726,Cuisinier,22]
// [Lecomte,Thomas,809-89-3792,Modéliste,4]
// [Gilles,Jacques,552-51-9742,Analyste financier,19]
// [Fernandes-Marie,Émile,147-82-6736,Cordiste,2]
// [Wagner,Théodore,895-17-8536,Technicien d'intervention clientèle gaz,29]
// [Legros,Léon,730-00-3598,Modiste,21]
// [Lacroix,Alain,205-45-2852,Matelot,9]
// [Simon,Denis,479-52-3614,Pédicure-podologue,0]
// [Prevost,Théophile-Denis,062-05-3813,Technicien,4]
// [Lamy,Claudine,306-12-9829,Chargé d'études ressources humaines,3]
// [Verdier,Sabine,246-91-1440,Chargé de clientèle banque,16]
// [Lecomte,André,521-87-5685,Dresseur d'animaux,4]
// [Paris,Antoine,380-48-8777,Technicien d'exploitation du réseau gaz,28]
// [Roy-Richard,Agnès,542-09-9894,Maquettiste,39]
// [Duhamel,Inès,751-51-2210,Traducteur-interprète,2]
// [Texier,Capucine,090-42-7289,Souffleur de verre,40]
// [Charles,Lucas,909-58-9472,Magasinier cariste,6]
// [Morvan,Bertrand,362-84-0382,Chargé des relations publiques,9]
// [Laine,Chantal,486-40-0066,Chef de chantier,29]
// [Colas,Thérèse,173-11-1308,Hot liner,7]
// [Allain,Thérèse,317-43-4319,Chef de produit touristique,35]
// [Leclerc,Cécile,329-26-0369,Rudologue,7]
// [Lopez,Roland,179-05-9349,Testeur en informatique,6]
// [Brun,Martine,986-07-0410,Élagueur,11]
// [Giraud-Gautier,Élisabeth,721-00-2370,Bijoutier,16]
// [Hamon,Jeannine-Camille,160-85-8720,Enseignant humanitaire,46]
// [Foucher,Auguste,788-99-7842,Ingénieur réservoir,38]
// [Pasquier-Jacob,William,339-36-8514,Ethnologue,10]
// [Le,Thierry,951-20-3368,Podo-orthésiste,33]
// [Courtois,Édouard,834-15-0160,Secrétaire médical,24]
// [Breton,Henri,126-88-2580,Administrateur judiciaire,18]
// [Fournier,Sébastien,276-11-4547,Technicien,39]
// [Legros,Marthe,811-57-4571,Ingénieur cloud computing,45]
// [Teixeira,Yves,752-12-5150,Décorateur scénographe,7]
// [Martins,Luce,403-25-2058,Projectionniste,31]
// [du,Capucine,466-36-0577,Technicien en engins de travaux publics,40]
// [Poulain,Georges-Victor,794-29-7996,Médiateur,14]
// [Delattre,Michelle,056-74-1823,Technicien de forge,21]
// [Chevalier-Perez,Noël,029-88-2944,Développeur humanitaire,46]
// [Dupre,Capucine,662-02-2160,Volcanologue,10]
// [Adam-Blin,William,505-23-4107,Agent de la surveillance SNCF,24]
// [Klein,Timothée,559-19-7906,Chargé de production,16]
// [Le,Raymond,867-26-8213,Opérateur sur machine à commande numérique,42]
// [de,Agnès,288-66-9010,Assistant,15]
// [Laroche,Margot,969-81-1603,Conducteur de machines à imprimer,44]
// [Marie,Charlotte,811-41-1708,Qualiticien,22]
// [Guillot,Juliette,714-68-0439,Officier de police,18]
// [Guibert,Renée,761-52-2601,Libraire,34]
// [Brun-Weiss,Geneviève,492-96-6942,Façonnier des industries graphiques,39]
// [Bourgeois-Gros,Bertrand,646-51-6872,Chef de fabrication des industries graphiques,21]
// [Mendes,Richard,734-02-7399,Chef de mission humanitaire,12]
// [de,François,718-30-9027,Illustrateur,8]
// [Blot,Michel,370-24-7854,ingénieur,6]
// [du,Julien,243-62-7302,Ergonome,4]
// [Charpentier,Paul,205-64-2562,Enquêteur privé,12]
// [Grondin,Charlotte,035-39-2066,Conducteur de machines à imprimer,9]
// [Leconte,Marguerite,342-14-2047,Conservateur du patrimoine,1]
// [Guilbert,Georges,996-71-8950,Testeur en informatique,6]
// [Boulay,Théophile,046-40-7835,Ingénieur,45]
// [Besnard,Catherine,247-77-8754,Administrateur de base de données,22]
// [Leroy,Élise,912-89-4498,Gestionnaire de contrats d'assurance,39]
// [Letellier,Grégoire,855-53-7220,Ingénieur en construction automobile,29]
// [Voisin,Michel,178-96-0802,Syndic de copropriété,40]
// [Moreau,Honoré,231-54-3515,Chargé d'études économiques,15]
// [Legendre,Danielle,384-76-2232,Maroquinier,1]
// [Giraud,Franck,042-27-0441,Technicien d'essais,2]
// [Gonzalez,Édouard,906-20-4458,Responsable de formation,40]
// [Coste,Nathalie,748-02-0553,Consignataire de navire,12]
// [Legrand,Isaac,396-74-3409,Pédicure-podologue,8]
// [Gonzalez,Édouard,572-60-1899,Éditeur,37]
// [du,Jacques,750-29-8620,Responsable du recrutement,3]
// [Georges,Benjamin,228-58-8383,Sous-officier de l'armée de terre,11]
// [Hoarau,Josette,673-96-9524,Secrétaire juridique,5]
// [de,Bertrand,525-03-4501,Commissaire de police,1]
// [Traore,Michelle,528-84-2647,Ingénieur en aéronautique,18]
// [Fournier,Marc,902-74-7709,Designer d'interaction,6]
// [Bonnet,Christophe,054-48-5314,Administrateur de base de données,27]
// [Guichard,Mathilde,037-70-6519,Chef de mission humanitaire,11]
// [Marin,Mathilde,803-17-5488,Chef de projet sites et sols pollués,4]
// [Lefevre,Jean,990-53-8127,Comédien,3]
// [Peltier,Jacqueline,529-09-9538,Reporter-photographe,44]
// [Parent-Vasseur,Corinne,916-78-7823,Webdesigner,12]
// [Voisin-Perrin,Arnaude,408-00-3766,Directeur,10]
// [Perrin,Nathalie,958-51-4023,Sapeur,15]
// [Blanchet,Nath,598-59-0811,Sérigraphe,24]
// [Perret,Alice,543-02-9892,Responsable biométrie,23]
// [Le,Alix,217-54-6253,Costumier,12]
// [Hoarau,Amélie,853-31-5033,Avocat,6]
// [Duhamel,Marc,340-73-2587,Chef de chantier,1]
// [Hoareau,Hélène,259-22-6065,Qualiticien,15]
// [Lamy,Charles,612-07-9646,Assistant dentaire,29]
// [Leduc,Henri,366-21-7760,Chef de produit marketing,27]
// [Delannoy,Marcel,908-04-1520,Vendeur en micro-informatique et multimédia,26]
// [Moreno,Adrien,590-05-5462,Audioprothésiste,24]
// [Chartier,Diane,413-51-9570,Domoticien,36]
// [Laine-Moreau,Emmanuel,243-41-7773,Agent de service commercial train,3]
// [Vincent,Jeanne,538-98-3516,Spécialiste des affaires réglementaires en chimie,29]
// [Lambert,Suzanne-Joséphine,492-71-8194,Ingénieur process aval,8]
// [Clerc,Thierry-Gérard,204-71-8514,Chargé,42]
// [Joseph,Zoé,741-53-8180,Convoyeur de fonds,1]
// [Mathieu,Bernard,953-33-5521,Chef de projet informatique,22]
// [Marchand,Brigitte,839-07-1920,Bio-informaticien,43]
// [Bertrand,Pierre,705-86-9540,Verrier au chalumeau,0]
// [Le,Henriette,719-14-3645,Professeur de maths ou de physique-chimie,14]
// [Chauvin,Valentine-Camille,606-88-8657,Orfèvre,36]
// [du,Aurore,839-30-0283,Audioprothésiste,28]
// [Vasseur,Léon,154-55-6100,Attaché,29]
// [Regnier-Faure,Frédéric,780-37-8662,Opérateur en traitement des matériaux,37]
// [Chevalier,Célina,282-75-0508,Cadreur,1]
// [Robert,Théodore,942-69-3730,Technicien céramiste,26]
// [de,Frédérique,306-17-8794,Responsable de réseau eau potable,1]
// [Torres,Alexandria,984-68-2533,Fleuriste,6]
// [Prevost,Matthieu,264-33-8132,Pilote de ligne automatisée,25]
// [Leconte,Anouk,868-90-0131,Pâtissier,3]
// [Laurent,Anaïs,238-97-2134,Facteur d'instruments,32]
// [Brunel-Monnier,Chantal,460-07-5693,Ingénieur de la police technique et scientifique,15]
// [Lacroix,Inès,780-57-5106,Entraîneur,15]
// [Lelievre,Martin,322-65-6345,Professeur dans l'enseignement agricole,0]
// [Blanc-Maillot,Raymond,940-29-6081,Ouvrier agricole,35]
// [Lejeune,Jean-Louis,150-46-5762,Médecin humanitaire,45]
// [Marie,Noémi,007-74-8103,Ingénieur télécoms et réseaux,40]
// [Techer,Nath,194-80-5033,Installateur en télécoms,20]
// [Bouvet,Thérèse,831-43-3475,Mécatronicien,35]
// [Wagner,Jérôme,031-05-1032,Aquaculteur,2]
// [Guillot-Barbier,Thierry,368-62-9450,Secrétaire juridique,40]
// [Allain,Martin,819-54-0936,Démographe,45]
// [Blanchet,Léon,182-78-5988,Sociologue,43]
// [Simon,Michelle,760-34-9488,Animateur du patrimoine,5]
// [Lombard,Lucy,019-91-0503,Chef de projet informatique,1]
// [Bertrand-Martel,Zacharie,542-21-4362,Chercheur en biologie du sport,8]
// [Da,Alphonse,085-26-2535,Journaliste reporter d'images,5]
// [Bourdon,Édouard,251-86-2667,Designer d'interaction,7]
// [Hoareau,Dorothée,122-94-6287,Animalier de laboratoire,14]
// [Sauvage,Anouk,577-05-0061,Sous-officier de l'armée de terre,44]
// [Francois,Zoé-Arnaude,085-04-8120,Climatologue,35]
// [Huet,Nathalie,368-69-2568,Chargé d'affaires en génie climatique,1]
// [Bazin,Julien,028-17-0883,Ingénieur,19]
// [Etienne,Paul,516-81-7379,Technicien des industries du verre,24]
// [Renard,Lorraine,292-20-8050,Chargé de production,4]
// [Chauvin,Antoinette,472-08-7847,Canalisateur,31]
// [Leveque,Thibaut,858-07-1547,Soudeur,30]
// [Sanchez-Alves,Raymond,018-43-5758,Conducteur de travaux,34]
// [Jacob,Olivie,332-33-7917,Ingénieur en R et D en énergies renouvelables,30]
// [Gros,Élise-Adèle,047-67-7029,Conseiller en génétique,26]
// [Chauvin,François,401-63-6584,Responsable de laboratoire de contrôle en biologie,34]
// [de,Julie,391-66-1714,Ingénieur hydrogéomorphologue,18]
// [Faivre,Dominique,182-80-0693,Ingénieur production en mécanique,8]
// [Martinez,Jeannine,389-77-4708,Charcutier,2]
// [Bouchet,Jérôme,090-34-4262,Salesman,17]
// [de,Aurore,410-80-6994,Antiquaire,3]
// [Perrot,Victor-Bernard,574-46-2990,Conducteur de ligne de production alimentaire,40]
// [Robin,Joseph,322-33-9447,Ingénieur en énergie solaire,45]
// [Pierre,Laurence,896-07-3078,Directeur de magasin à grande surface,34]
// [Robin,Céline,908-40-2983,Mécanicien d'entretien d'avion,7]
// [Texier,Élisabeth,503-20-1222,Attaché,9]
// [du,Aimée,433-13-1668,Ingénieur systèmes embarqués,13]
// [Picard,Jules,915-93-4226,Conducteur de bus ou d'autocar,27]
// [Huet,Élise,204-19-2694,Caissier,4]
// [Fernandez,Zacharie,464-63-6240,Ingénieur cloud computing,23]
// [Mendes,Jeannine,121-95-3428,Employé de restaurant,37]
// [Denis,Aurélie,912-45-1506,Professeur de lycée professionnel ou technique,1]
// [Richard,Frédérique,462-40-1386,Ébéniste,10]
// [Hebert-Coulon,Suzanne,523-27-8174,Architecte web,5]
// [Barbe,Tristan,683-32-8410,Agent de développement local,46]
// [Lefort,Auguste,137-38-8764,Conseiller en économie sociale et familiale,22]
// [Gay,Noël,783-18-5014,Juriste en droit social,37]
// [Simon,Agnès,777-81-9089,Maçon,25]
// [Le,Françoise,569-51-6279,Responsable d'ordonnancement,11]
// [Sauvage,Xavier,821-70-0382,Céramiste,27]
// [Delahaye,Jeannine,881-70-8914,Guide conférencier des villes et pays d'art et d'histoire,40]
// [Olivier,Thierry,599-52-9541,Guide conférencier des villes et pays d'art et d'histoire,28]
// [de,Hortense,198-68-2890,Conseiller en séjours,35]
// [Potier,daisy,323-56-7354,Informaticien,11]
// [de,William,538-91-3406,Masseur-kinésithérapeute,5]
// [Perrot,Yves,590-59-2058,Éducateur,15]
// [Antoine,Alexandrie,050-03-4106,Microbiologiste,22]
// [Andre,Thierry,623-63-8179,Gestionnaire de portefeuille,22]
// [Delattre,Agnès,187-08-5275,Volcanologue,14]
// [Garcia-Leroy,Alain,060-84-0939,Élagueur,36]
// [Rodrigues,Alphonse,739-18-7625,Employé de pressing,12]
// [Guilbert,Manon,249-16-9950,Conseiller en séjours,18]
// [Perret,François,035-13-7449,Installateur en télécoms,17]
// [Charpentier-Peltier,Émilie,707-09-0330,Hot liner,31]
// [Lemoine,Catherine,414-91-7162,Architecte produit industriel,26]
// [Gallet,Michel,347-95-3584,Sérigraphe,27]
// [de,Rémy,382-22-6955,Fleuriste,41]
// [Dupre,Marc,919-53-7815,Conducteur de machines agricoles,26]
// [Chartier,Alfred,853-27-3490,Ingénieur études et développement en logiciels de simulation,18]
// [Arnaud,Margot-Noémi,543-93-3057,Auditeur externe,16]
// [Marechal-Joseph,Léon,453-03-9221,Spécialiste des affaires réglementaires en chimie,10]
// [Guichard,Cécile,765-06-0853,Botaniste,34]
// [Vidal,Julien-Jules,173-93-3575,Biologiste en environnement,4]
// [Giraud,Paulette,436-57-5612,Techniverrier,38]
// [Faivre-Henry,Lucas,220-70-1072,Façonnier des industries graphiques,7]
// [Le,Juliette,526-52-2514,Juriste en propriété intellectuelle,29]
// [Leclercq,Olivie,113-57-9459,Pédiatre,28]
// [Germain,Isabelle,214-85-0487,Souffleur de verre,33]
// [Evrard,Josette,346-99-3297,Professeur de lycée professionnel ou technique,7]
// [Andre,Alphonse-Thomas,122-63-5219,Ingénieur nucléaire,23]
// [Wagner,Franck-Gilles,889-32-3624,Chef de station de traitement des eaux,25]
// [Pasquier,Paulette,108-27-7393,Musicien,19]
// [Briand-Lefevre,Patricia,667-19-6027,Charpentier bois,37]
// [Bazin,Antoine-Laurent,334-83-5129,Webmestre,21]
// [Thomas,Julien,551-24-0744,Mécanicien,42]
// [Rolland-Meyer,Honoré,922-10-7949,Chef de rayon,11]
// [Maury-Guillot,Timothée,921-65-0391,Gestionnaire de contrats informatiques,18]
// [Lemaire,Anastasie,088-47-8671,Domoticien,35]
// [Martineau-Brunel,René,321-69-2001,Puériculteur,17]
// [Blot,William,256-98-6560,Gardien de police municipale,8]
// [Le,Zacharie,980-19-6178,Inspecteur,7]
// [Delorme,Frédéric,787-10-3771,Ingénieur de la police technique et scientifique,41]
// [Chevalier,Agathe,559-58-0157,Professeur de lycée professionnel ou technique,19]
// [De,Camille,652-60-8294,Expert bilan carbone,6]
// [Bonneau,Audrey,576-40-5707,Chargé de clientèle banque,28]
// [Lemaitre,Honoré,476-08-9367,Éducateur de la protection judiciaire de la jeunesse,29]
// [Lecomte,Diane,995-43-6588,Salesman,33]
// [Denis,Lucas,448-32-9816,Charpentier bois,26]
// [Navarro,Valérie-Valentine,009-58-2160,Militaire technicien,1]
// [Sauvage-Chauveau,Noël,699-58-0792,Biostatisticien,1]
// [Martin,David,551-52-1480,Charpentier métallique,42]
// [Langlois,Paulette,827-83-5870,Oenologue,39]
// [Fouquet,Timothée,631-28-0561,Tonnelier,44]
// [Guerin,Frédérique,744-90-3977,Architecte,26]
// [Lefevre-Bernier,Célina,060-43-7949,Chef de produit touristique,42]
// [Benard,Daniel-Grégoire,958-16-4636,Greffier,36]
// [Bouchet,Odette,082-70-2135,Céramiste,12]
// [Monnier,Bernadette,172-20-5392,Attaché de presse,8]
// [Guillot,Marc,617-12-8657,Animateur de bassin versant,19]
// [Le,Éric,220-62-0998,Chargé de recherche en acoustique musicale,27]
// [Simon,Michel,540-24-6658,Greffier,31]
// [Bousquet,Matthieu,021-74-3507,Guide conférencier des villes et pays d'art et d'histoire,36]
// [Garcia,Monique,205-23-0769,Caviste,5]
// [Roy,Renée,425-90-8601,Chercheur en biologie du sport,26]
// [Gautier,Frédéric,756-51-3246,Climatologue,7]
// [Besnard,Jérôme,824-08-5566,Orthophoniste,22]
// [Guibert,Agathe,814-33-1641,Responsable de la rémunération,27]
// [Leblanc,Frédéric,198-04-5135,Boucher,18]
// [de,Valérie,678-07-6328,Ouvrier,33]
// [de,Édouard,298-87-4215,Chef de fabrication des industries graphiques,0]
// [Coste-Guibert,Théophile,566-67-7443,Technicien en métrologie,46]
// [Tanguy,Étienne,601-62-4914,Illustrateur,24]
// [David,Nicole-Susanne,843-41-8240,Monteur en réseaux de distribution électrique,9]
// [Maillet,Raymond,867-93-2428,Chargé d'études naturalistes,8]
// [Brunet,Jérôme,813-68-5249,Analyste de crédit,18]
// [Seguin,Julie,003-04-5455,Juge d'instance,31]
// [Bonnin,David,303-98-4999,Credit manager,24]
// [Bailly,Édith,649-34-2683,Responsable de scierie,12]
// [Pottier-Bonneau,Hortense,106-69-1278,Diététicien,14]
// [Buisson,Georges,963-52-0930,Technicien des industries du verre,34]
// [Lemaire,Étienne,696-54-6288,Maréchal,10]
// [Boutin-Lombard,Geneviève,454-23-8560,Chargé de pharmacovigilance,2]
// [du,Pierre,056-48-4444,Ingénieur en informatique,46]
// [Le,Mathilde,595-53-8887,Barman,25]
// [de,Aimée,719-09-0924,Chargé,29]
// [Garnier,Dominique,748-38-9169,Clerc d'huissier,23]
// [Rey,Éric,751-12-1417,Ingénieur gaz,29]
// [Lemaire-Michel,Alain,398-50-1618,Manipulateur en électroradiologie médicale,9]
// [Navarro,Louis,765-11-8476,Notaire,16]
// [Pereira,Jacques,471-25-5659,Hydrogéologue,8]
// [du,Capucine,956-93-4169,Ingénieur production dans les biotechnologies,43]
// [Chauvet,Christophe-Émile,238-16-8140,Conseiller d'orientation-psychologue,6]
// [Robert,Véronique,859-86-8360,Informaticien,14]
// [Vincent,Jacques,796-96-1447,Rédacteur,2]
// [Neveu-Noel,Yves,960-96-8480,Designer,5]
// [Torres,Nicolas-Arthur,641-44-0299,Géotechnicien,32]
// [Martins,David,863-90-0212,Rudologue,7]
// [Remy,Manon,646-53-8904,Halieute,14]
// [Bousquet,Chantal,696-23-9252,Courtier,35]
// [Foucher-Durand,Olivier,559-49-9766,Professeur de musique et de danse,27]
// [Martinez,Xavier,206-69-9437,Serrurier,18]
// [Pereira,Jeanne-Geneviève,596-32-7235,Professeur de musique et de danse,19]
// [de,Arthur,375-40-7924,Technicien des industries du verre,39]
// [Laine,Zoé,554-52-5438,Consultant,41]
// [Lefort,William,884-06-2694,Technicien de maintenance industrielle,43]
// [Aubert-Alexandre,Isaac,833-48-6115,Attaché,42]
// [Gimenez,Hélène,553-55-1042,Technicien d'intervention clientèle gaz,14]
// [Costa,Audrey,625-19-6148,Staffeur-ornemaniste,33]
// [Germain,Maryse,687-24-5229,Botaniste,30]
// [Jacquot,Christelle,092-39-9039,Éditeur,32]
// [Guyot,Stéphane,632-02-7291,Officier de l'armée de l'air,11]
// [Camus,Louise,532-51-7481,Pédicure-podologue,32]
// [Dumont-Couturier,Étienne,587-54-5368,Technico-commercial en agroalimentaire,3]
// [Gallet,Isaac,373-36-6646,Ingénieur environnement et risques industriels,2]
// [Levy-Blanchet,Adrien,783-06-7658,Chef de projet éolien,30]
// [Pruvost,Georges,058-10-5111,Sérigraphe,17]
// [Delorme,Richard-Henri,028-96-7803,Technicien de forge,16]
// [Berger,Pierre,482-96-2190,Chargé de recherche et développement déchets,8]
// [du,Guy,795-38-7415,Analyste de crédit,9]
// [Dumas,Maggie,708-57-6334,Technicien de maintenance en informatique,39]
// [Antoine,Bertrand,173-23-5339,Directeur de restaurant,15]
// [Pelletier-Morel,Lucas,465-05-5314,Secrétaire administratif,31]
// [Chauveau,Alain,997-16-8865,Ajusteur,46]
// [Mercier,Noémi-Inès,798-77-1037,Administrateur de spectacle,5]
// [Peltier,Théophile,336-68-6823,Volcanologue,23]
// [Camus,Alfred,823-47-2315,Accompagnateur de moyenne montagne,13]
// [Blin-Delaunay,Léon,048-27-1037,Ingénieur,37]
// [Pinto,Alexandria,212-89-6081,Éditeur,22]
// [Grenier,Léon,879-40-7312,Carreleur-mosaïste,39]
// [Berthelot,Michèle,523-86-9305,Ferronnier d'art,29]
// [Aubert,Danielle-Adrienne,182-69-3926,Souffleur de verre,13]
// [Schmitt,Franck,067-09-5875,Administrateur de réseau,36]
// [Techer,Anastasie,737-04-8182,Éducateur de jeunes enfants,25]
// [Maurice,Audrey,917-02-2185,Contrôleur de gestion,14]
// [Martinez,Stéphane-Gabriel,101-49-1282,Charpentier bois,20]
// [Rousset,Thibaut,945-45-5571,Employé de restaurant,4]
// [de,Jean,516-29-2500,Chef de rayon,23]
// [du,Émile,797-44-8462,Danseur,40]
// [Teixeira,Michèle,786-28-5360,Hydrogéologue,9]
// [Pichon,Alain-Henri,056-34-4838,Géomaticien,1]
// [Ollivier,Susan,368-25-2255,Manager de risques,24]
// [Lebon,Céline,810-42-8345,Chargé d'études en marketing,35]
// [Bruneau-Goncalves,Martin,564-78-7354,Dessinateur BTP,41]
// [Regnier,Richard,229-75-1604,Ingénieur fluides, énergies, réseaux, environnement,30]
// [Duval,Gilles,355-68-4383,Conducteur d'engins de travaux publics,8]
// [Jacquot,Jacques,673-42-7413,Technicien de police technique et scientifique,2]
// [Ribeiro,Anastasie,175-60-8181,Analyste financier,40]
// [Royer-Martins,Benjamin,793-64-9177,Technicien de maintenance en informatique,1]
// [Gosselin,Madeleine,114-69-9384,Chercheur en biologie du sport,46]
// [Briand,Camille,228-71-2014,Astrophysicien,5]
// [Jacques,Paulette,287-49-4890,Agronome,36]
// [Jacquet,David-Marc,191-28-0445,Technicien en lignes haute tension,40]
// [Clement,Marthe,601-87-2036,Staffeur-ornemaniste,3]
// [David,Alexandre,975-63-1020,Audioprothésiste,4]
// [Dupuy,Sylvie,192-32-5375,Logisticien,40]
// [Giraud-Colin,Thierry,951-05-5421,Auxiliaire de puériculture,3]
// [Olivier,Rémy,582-29-2420,Agenceur de cuisines et salles de bains,12]
// [Martinez,Geneviève,688-43-7011,Coordonnateur d'études cliniques,35]
// [Collin,Frédéric,386-49-0866,Photographe,12]
// [Becker,Frédéric-Rémy,348-99-3830,Ingénieur métallurgiste,3]
// [Le,David,567-79-5358,Officier,4]
// [Denis-Ribeiro,Benoît,483-26-1555,Agent des méthodes,42]
// [Lemonnier,Patrick,626-54-6966,Technicien chimiste,9]
// [Jacquet,Joseph,766-66-9434,Prothésiste dentaire,43]
// [Guyot,Denis,223-33-7807,Sportif de haut niveau,22]
// [Marques,Alexandrie,681-04-0356,Tailleur de pierre,41]
// [Vincent,Nicole-Laetitia,149-61-6059,Directeur d'hôpital,36]
// [Dupuy,Olivier,475-84-1040,Consultant,46]
// [Leroux,Maryse,717-05-7961,Ingénieur d'application,10]
// [de,Célina,962-40-9366,Sous-officier de l'armée de l'air,44]
// [Cordier,Maggie,748-21-4511,Ingénieur réservoir,26]
// [Le,Nathalie,231-96-5637,Infirmier,35]
// [Gaillard,Alexandria,571-50-7119,Credit manager,30]
// [Delorme,Théophile,906-50-0414,Vétérinaire,30]
// [Arnaud,Stéphane-Paul,161-95-5149,Orthophoniste,30]
// [Fontaine,Gérard,877-36-7464,Ingénieur efficacité énergétique du bâtiment,9]
// [Lefebvre,Sébastien,651-17-9786,Hôte d'accueil,20]
// [Mahe-Breton,Maryse,327-29-2548,Magasinier cariste,21]
// [Guyot,Josette,416-74-4879,Sellier,37]
// [Adam,William,891-20-4040,Ingénieur production dans les biotechnologies,32]
// [Godard,Cécile,860-81-5446,Technicien plasturgiste,6]
// [Guichard,Stéphane,015-38-3966,Préparateur en pharmacie,24]
// [Dos,Éléonore,927-56-6386,Officier de gendarmerie,38]
// [Dumont,Pauline,560-83-2052,Orthoptiste,13]
// [de,Astrid,986-95-1299,Psychomotricien,1]
// [Julien,Denis,352-54-7176,Sage-femme,20]
// [Jacquet,Gérard,176-79-2838,Chef de projet démantèlement nucléaire,12]
// [Weber,Christophe,837-56-5197,Ergothérapeute,37]
// [Julien,Yves,031-29-1985,Technicien d'essais,25]
// [Traore,Gilles,762-64-2219,Gardien de police municipale,21]
// [Vallet,Stéphane-Thibault,028-26-0914,Façadier,14]
// [Chauvin,Théophile,377-23-4778,Ingénieur plasturgiste,2]
// [Barre-Barbe,daisy,398-06-3085,Hot liner,9]
// [Guillaume,Denis,665-53-7623,Démographe,42]
// [Daniel,Henri-Sébastien,696-66-3075,Moniteur,30]
// [Philippe,Victoire,691-52-1062,Ingénieur en électronique numérique,21]
// [Lemaitre,Brigitte,985-27-9020,Pilote de ligne,23]
// [Gallet,Louis,960-01-9962,Conseiller espace info-énergie,15]
// [Masson,Caroline,067-19-5416,Webmestre,22]
// [Lecoq,Matthieu-William,016-39-9064,Économe de flux,9]
// [Langlois,Éric,556-02-9294,Animateur,13]
// [Turpin,Luc-Arthur,393-78-9693,Courtier,4]
// [Robin-Weber,Auguste,743-00-2784,Maroquinier,45]
// [Camus,William,686-27-8505,Conseiller en économie sociale et familiale,30]
// [Delahaye,Anaïs-Diane,874-00-2471,Actuaire,1]
// [Charpentier-Huet,Thomas,015-73-5445,Agent d'assurances,24]
// [Leger,Inès,089-53-4563,Gardien de police municipale,42]
// [Le,Michèle,341-86-0543,Chargé d'études naturalistes,17]
// [Guillou-Henry,Josette,678-78-5030,Toiletteur d'animaux,17]
// [Lopez,Pierre,611-62-0305,Moniteur,26]
// [Leclercq,Victor,823-72-2893,Inspecteur de banque,3]
// [Hoareau,Anastasie,319-06-2698,Céramiste,19]
// [Gilles,Noël,392-73-1688,Technicien de maintenance industrielle,25]
// [Buisson,Philippe,271-69-7924,Géophysicien,1]
// [Toussaint,Marc,295-80-7026,Chargé de recherche et développement déchets,15]
// [Dijoux,Marc,482-68-2188,Climatologue,2]
// [Dumont,Corinne,658-11-1720,Aérodynamicien,42]
// [Meyer-Gros,Inès,349-49-2634,Auditeur interne,3]
// [Langlois,André,413-94-8203,Ingénieur,11]
// [Lemaitre,Noémi,786-33-4300,Directeur,10]
// [Bodin,Claudine,887-03-9518,Concepteur de niveaux de jeu web,19]
// [Pires,Noémi,057-52-7781,Éditeur,12]
// [de,Claudine,619-66-2912,Chercheur en physique,5]
// [Loiseau,Augustin,726-65-6215,Sportif de haut niveau,24]
// [Raymond-Pruvost,Christelle,560-43-6632,Chef de mission humanitaire,45]
// [Gomes,Aurélie,084-14-7973,Barman,45]
// [Lefevre,Danielle,593-11-0166,Secrétaire,17]
// [Lacroix,Gilles,181-78-8258,Responsable assurance qualité,31]
// [Masse,Corinne,373-20-2725,Inspecteur,22]
// [de,Aurélie,649-56-3296,Boulanger,2]
// [Guillou,Michelle,132-37-8097,Inspecteur de banque,26]
// [du,Victor,103-14-1982,Médiateur,40]
// [Gomes,Roger,102-11-8950,Entraîneur,1]
// [Levy,Louis,864-50-8129,Monteur en réseaux de distribution électrique,27]
// [Leroy-Lucas,Hugues,295-91-8329,Télévendeur,10]
// [Ferreira,Jérôme,636-04-0513,Chef de cultures légumières,34]
// [Lacombe,Marguerite,318-12-6728,Agriculteur,26]
// [Tanguy,Caroline,703-80-7879,Ingénieur en métrologie,20]
// [Charpentier,Zacharie-Augustin,282-76-0241,Antiquaire,41]
// [Leclerc,Étienne,377-85-1298,Médecin humanitaire,2]
// [Giraud,Gilbert,226-22-5196,Agent de développement des énergies renouvelables,1]
// [Begue,Robert-Martin,741-30-6541,Garde à cheval,41]
// [Lombard-Dijoux,Adrienne,101-40-1981,Chef de chantier,10]
// [Charles,Théophile,522-20-2979,Conducteur de métro,30]
// [Chartier,Guy,202-98-9533,Conseiller en séjours,39]
// [Turpin,Colette,729-64-5998,Ethnologue,10]
// [Chretien-Clerc,Emmanuel,321-97-7041,Ingénieur environnement,3]
// [Olivier,Thomas,097-55-0121,Statisticien,42]
// [de,Édith,435-86-1528,Agent d'assurances,21]
// [Maury-Rey,André,675-59-4801,Opérateur sur machine à commande numérique,9]
// [Munoz,Anne,720-06-0628,Plâtrier,44]
// [Marques,Gabriel,984-70-5078,Conducteur de métro,14]
// [De,Philippe,533-48-6545,Audioprothésiste,16]
// [Germain,Benjamin,674-10-8941,Psychomotricien,3]
// [Nicolas,Eugène,702-86-8971,Vendeur en fournitures automobiles,14]
// [Legendre,Michelle-Constance,411-85-0041,Chanteur,28]
// [Herve,Margaux,274-75-7994,Ingénieur recherche et développement en agroalimentaire,10]
// [Millet,Lucy,356-26-3347,Gardien de police municipale,35]
// [Charpentier,Jeanne,304-51-9632,Administrateur de base de données,11]
// [Diallo,Gérard,189-88-8996,Audioprothésiste,5]
// [Chartier,Denis,011-02-2923,Ingénieur textile,18]
// [de,Élise,513-04-0168,Serrurier,15]
// [Rodrigues,Clémence,215-39-4443,Projectionniste,17]
// [Dupont,Emmanuel,414-38-3388,Sapeur,23]
// [Fabre,Rémy,703-13-8386,Technicien de fabrication de mobilier et de menuiserie,0]
// [Maillet-Roche,Diane,431-42-7713,Officier de la marine marchande,1]
// [Lacombe,Timothée,721-69-3277,Cordonnier,8]
// [Langlois,Lucas,959-98-5301,Décorateur scénographe,19]
// [David,Joseph,034-56-8053,Secrétaire administratif,29]
// [du,Augustin,432-38-8929,Attaché de recherche clinique,30]
// [Vasseur,Manon,328-04-8277,Responsable de la promotion des ventes,12]
// [Paul,Gilles,688-64-2366,Ingénieur forage,35]
// [Andre,Richard,726-50-6589,Enseignant humanitaire,4]
// [Didier-Gautier,Joséphine,581-29-5155,Agent de transit,30]
// [de,Alfred,876-13-0722,Ingénieur méthodes mécaniques,26]
// [Guillet,Frédéric,292-44-9214,Optronicien,40]
// [Le,Eugène,552-83-2175,Médecin généraliste,8]
// [Lemonnier-Costa,Lucy,497-69-2561,Architecte d'intérieur,14]
// [Gay,Théophile,617-94-9155,Commercial export,4]
// [Caron,David,018-55-6997,Grutier,27]
// [Boulanger,Charles,611-97-3347,Attaché de recherche clinique,30]
// [Dos,Stéphane,973-10-3284,Attaché d'administration,20]
// [de,Thomas,593-20-8662,Charpentier bois,16]
// [Legrand,Alphonse,161-55-2976,Assistant de service social,39]
// [Delattre,Hugues-Alphonse,403-71-1723,Mécanicien en matériel agricole,38]
// [du,Tristan,967-58-8091,Musicien,16]
// [Charpentier,Céline,432-92-5602,Pâtissier,21]
// [de,Alfred,509-05-5435,Verrier au chalumeau,27]
// [Bruneau,Juliette,081-99-0661,Géologue modélisateur,2]
// [Delorme,Raymond-Zacharie,190-10-7717,Projectionniste,4]
// [Roy,Grégoire,887-64-4394,Modéliste,44]
// [Navarro,Roger,301-84-1076,Cuisinier,35]
// [Reynaud,Aurélie-Nathalie,958-92-8269,Conseiller en environnement,29]
// [Perrin,Alex,082-27-3401,Cuisinier,33]
// [Gallet,Henri,388-68-9188,Ingénieur,30]
// [Collet-Dumas,Yves,100-83-3882,Météorologiste,21]
// [Neveu,Valentine,672-52-5822,Secrétaire d'édition,35]
// [Hebert,Jacqueline-Camille,574-09-1657,Professeur documentaliste,14]
// [Lesage,Jules,431-75-0198,Contrôleur de performances,41]
// [Hoareau,Thérèse,607-37-3764,Boulanger,9]
// [Da,Joséphine,023-77-3235,Horloger,17]
// [Humbert,Léon,308-90-5828,Acheteur,23]
// [Rolland,Alix,453-33-0575,Ingénieur,28]
// [Mathieu,Louise,906-73-4794,Tailleur de pierre,27]
// [Poirier,Richard,421-10-9627,Traducteur-interprète,8]
// [Morel,Vincent,067-89-5404,Halieute,17]
// [Marchal,Gérard,231-72-1389,Aquaculteur,20]
// [Joly,Colette,176-51-7046,Céramiste,34]
// [Joubert,Robert,884-83-8039,Réceptionniste,1]
// [Colin,Emmanuel,801-55-1814,Chef d'exploitation d'usine d'incinération,1]
// [du,Nicolas,109-52-0183,Astrophysicien,20]
// [Lucas,Susan,991-10-3877,Conducteur de machines agricoles,12]
// [Marques,Laurent,010-70-9089,Ingénieur en informatique,27]
// [Faivre,Victoire,372-61-4234,Lad-jockey, lad-driver,2]
// [Da,Amélie,500-09-9580,Technicien en traitement des déchets,26]
// [Guibert,Richard,701-10-3280,Magasinier cariste,10]
// [Michel-Jacob,Isabelle,114-25-1838,Hôte d'accueil,37]
// [Lopes,Clémence,634-40-9003,Sportif de haut niveau,4]
// [Baudry,William,817-36-1920,Responsable des ressources humaines,30]
// [Guillon,Roland-Franck,237-51-9601,Agent de propreté et d'hygiène,7]
// [Collin,Maurice,870-09-6617,Assistant dentaire,19]
// [Coulon,Inès,267-42-8137,Pédologue,1]
// [Bertrand,Margaux-Émilie,942-97-8292,Rudologue,7]
// [Hamon,Diane,302-30-0155,Hydrologue,33]
// [Rossi,David,991-78-9673,Employé de pressing,24]
// [Bouvier,Arthur,009-52-1472,Boulanger,43]
// [Besson,David,750-54-0260,Sociologue,16]
// [Richard,Jacques,729-29-1212,Moniteur,15]
// [Guyot,Émilie,706-36-7321,Ingénieur,40]
// [Bodin,Hortense,828-17-8550,Horticulteur,31]
// [Georges-Pons,Philippe,736-10-4581,Agent de développement local,28]
// [Blot,Grégoire,953-53-0549,Volcanologue,17]
// [Moreau,Bertrand,944-56-5705,Chef des ventes,11]
// [Masson,Valérie,973-43-5531,Assistant,6]
// [Picard,Josette,717-24-3301,Enseignant,16]
// [Lefort,Jacqueline-Mathilde,562-48-3789,Maquettiste,10]
// [Raymond,Jean,294-87-6720,Cordiste,42]
// [Delaunay,Honoré,288-28-4212,Agronome,5]
// [Leger,Lucy-Louise,186-70-3900,Plombier,37]
// [Pages,Dorothée,954-34-1802,Psychomotricien,27]
// [Brun,Michèle,070-90-7636,Moniteur d'équitation,6]
// [du,Sabine,397-22-5539,Ingénieur essais,46]
// [Langlois-Ribeiro,Alex,719-54-7914,Chercheur en physique,22]
// ...
// [Guillou,Denise,829-53-5395,Agent de développement local,27]
// [Hebert,Sébastien,015-27-1486,Aromaticien,17]
// [Martel,Stéphane-Pierre,246-37-8408,Ethnologue,35]
// [Brunet-Benoit,Édith,053-17-4147,Fiscaliste,38]
// [du,Madeleine,680-93-2550,Consignataire de navire,21]
// [Neveu,Hortense,254-83-5250,Agent d'assurances,21]
// [Loiseau-Ruiz,Paulette,880-65-4001,Contrôleur,45]
// [Camus,Roger,967-62-2311,Technicien de forge,33]
// [Besson,Brigitte,295-51-5363,Collaborateur de notaire,41]
// [Hebert-Leger,Zoé,980-58-3733,Ingénieur télécoms et réseaux,33]
// [de,Laurent,565-11-9874,Bijoutier,4]
// [Pasquier,Alice,157-32-4024,Chargé d'études économiques,26]
// [Roux-Lebon,Camille,961-42-9881,Audioprothésiste,33]
// [Langlois,Philippine-Valérie,603-73-2052,Responsable de réseau eau potable,18]
// [Charles,Thomas,372-57-8737,Secrétaire juridique,19]
// [Berger,Stéphane,327-51-2815,Bijoutier,38]
// [Mercier,Franck,904-07-4974,Sous-officier de l'armée de l'air,2]
// [Guyot,Élodie,380-91-9082,Pâtissier,29]
// [Blanc,Victor,702-53-5350,Ouvrier agricole,17]
// [Marin,Amélie,241-71-2819,Ingénieur,32]
// [Loiseau,Aurélie,416-14-7752,Marin de commerce,14]
// [Teixeira,Anouk,537-37-2896,Auteur interprète,43]
// [Gilles,Camille,857-03-5513,Responsable du service après-vente,2]
// [Gomez-Traore,Cécile,217-43-6717,Sous-officier de l'armée de terre,32]
// [Aubert,Thierry,558-31-9857,Adjoint,19]
// [Richard,Eugène-Adrien,023-69-5390,Attaché d'administration,3]
// [Leclercq-Bailly,Thérèse,543-28-1291,Frigoriste,36]
// [Paris,Hortense,655-52-7937,Podo-orthésiste,22]
// [Mary,Arnaude,759-70-7544,Technico-commercial en agroalimentaire,11]
// [Michel,Joséphine,901-88-5025,Orthoptiste,31]
// [Marechal,Pénélope,629-41-3645,Technicien en lignes haute tension,3]
// [Pelletier,Thibault,608-07-9029,Chargé de production,5]
// [Martinez,Théodore,945-97-8983,Techniverrier,19]
// [Muller,Émile,080-51-0885,Économe de flux,38]
// [de,Aimé,031-26-5206,Bio-informaticien,23]
// [Gosselin,Éric-Alphonse,425-84-9681,Chef de publicité,19]
// [Levy,Jeannine,848-36-0453,Pâtissier,1]
// [Poulain,Joséphine,095-50-2867,Technicien de l'intervention sociale et familiale,20]
// [Jacquot,Zacharie,369-88-7452,Orthoprothésiste,41]
// [Masse,Julien,984-88-1453,Magistrat,29]
// [Perrot-Gonzalez,Patricia,989-10-7231,Ferronnier d'art,44]
// [Le,Édith,076-90-2394,Chargé de veille législative et réglementaire,35]
// [Sanchez,Manon,218-75-5008,Chercheur en chimie,1]
// [de,Aimée,054-20-7845,Responsable du recrutement,37]
// [Huet,Gilles,563-16-7857,Opérateur sur machine à commande numérique,17]
// [Fischer-Moulin,Jeanne,223-31-3617,Architecte,15]
// [Lemonnier,Andrée,386-58-6694,Contrôleur,18]
// [Noel-Guichard,Isabelle,334-32-3053,Mécanicien moto,2]
// [Petitjean,Olivier,753-98-6193,Substitut du procureur,31]
// [Barbe,Anastasie-Valentine,805-80-5422,Artiste de cirque,24]
// [Godard,Alfred,763-40-2020,Militaire technicien,31]
// [Morin-Le,Aimé,663-91-8875,Officier de la marine marchande,2]
// [Lemonnier,Léon,318-07-8250,Géomaticien,33]
// [Munoz,Martine,281-24-0060,Assistant,32]
// [du,Geneviève,556-63-5824,Collecteur de fonds,35]
// [Carre,Corinne,360-50-5008,Hôtesse de l'air,39]
// [Robin,Noémi,195-96-3633,Ingénieur maintenance aéronautique,1]
// [Petitjean-Hardy,Philippe,577-13-7884,Ingénieur maintenance aéronautique,22]
// [Le,Roger,160-82-9333,Mandataire judiciaire,9]
// [Grenier,Marie,721-52-8027,Acheteur,34]
// [Collet,Martine,882-44-3246,Tailleur,7]
// [Brunet,Christiane,967-45-4762,Designer d'interaction,37]
// [Le,Marianne,609-79-0134,Chef de fabrication des industries graphiques,20]
// [Benoit-Coste,Adèle,042-73-3870,Conseiller agricole,37]
// [Gauthier,Audrey,340-82-0027,Ingénieur,1]
// [Rolland,Guy,475-88-1812,Entraîneur,36]
// [Charrier,Théophile,803-74-3762,Cordiste,6]
// [Guerin,Adélaïde,103-45-4108,Modiste,46]
// [Vaillant-Seguin,Marianne,185-55-4714,Déclarant en douane,34]
// [de,Michelle,054-14-3272,Chargé d'études ressources humaines,33]
// [Hubert,Antoine,139-30-1179,Responsable de réseau eau potable,37]
// [de,Christine,593-30-2579,Médiateur,19]
// [Bonneau,Denise,307-20-5679,Horloger,29]
// [Leroy,Auguste,837-75-8625,Cuisinier,35]
// [Gomez,Paulette,997-53-8397,Pharmacien dans l'industrie,22]
// [Raymond,Nicolas,513-69-7673,Bio-informaticien,30]
// [Fernandes,Agathe,060-50-1204,Responsable de la rémunération,14]
// [Coste-Carre,Lucy,361-19-2226,Ingénieur process aval,22]
// [Leroux,Laetitia,555-55-3416,Concepteur multimédia,29]
// [Gauthier-Leleu,Alex,873-24-5468,Webdesigner,7]
// [Bonneau,Simone,187-20-7972,Expert automobile,13]
// [Techer,Jacques-Gabriel,694-94-5545,Techniverrier,2]
// [Lemoine,Pierre,766-13-0094,Chargé de communication interne,15]
// [Barthelemy,Roger,611-04-6034,Auxiliaire de puériculture,10]
// [Auger,Maggie,677-71-6174,Photographe,40]
// [Meunier,Françoise,880-14-8603,Chargé de production,35]
// [Rousset,Patricia-Maryse,892-30-8347,Inspecteur du permis de conduire et de la sécurité routière,38]
// [Le,Andrée,845-72-6914,Chargé d'études en aménagement,16]
// [Andre,Diane,735-13-8838,Orfèvre,39]
// [de,Noël,910-21-5333,Psychomotricien,19]
// [Tessier,Diane,862-73-2560,Moniteur de ski,4]
// [Hubert,Élodie-Anne,912-52-8899,Avocat,1]
// [du,Julien,339-49-5168,Ingénieur fluides, énergies, réseaux, environnement,4]
// [Pineau,Bertrand,350-14-1077,Expert en sécurité informatique,43]
// [Colin,Luc,539-04-9093,Gardien de la paix,26]
// [Perrin,Timothée,862-27-1125,Monteur,41]
// [Dupuy,Nathalie,855-09-9725,Maroquinier,45]
// [Hoareau,Grégoire-Jérôme,542-71-5958,Staffeur-ornemaniste,21]
// [Roux,Stéphane,941-21-1156,Analyste de crédit,24]
// [Evrard,Philippine,336-62-8485,Conseiller en économie sociale et familiale,38]
// [Pascal,Marie,591-45-4700,Responsable micro,7]
// [Merle-Payet,Thomas,120-99-0835,Barman,2]
// [Nguyen,Martine,801-19-6669,Architecte réseau,2]
// [Charpentier,Michelle,879-19-3731,Chargé d'affaires en génie mécanique,13]
// [de,Paul,190-10-4512,Diététicien,19]
// [Becker,Alexandria,800-90-7154,Agent de propreté urbaine,1]
// [Roger-Charles,Martine,147-78-6265,Ingénieur systèmes embarqués,29]
// [de,Agathe,255-76-5991,Conducteur de travaux,43]
// [Fabre,Aimée,458-65-7943,Conseiller espace info-énergie,25]
// [Lombard,Hugues,132-67-3668,Chargé d'affaires en génie mécanique,42]
// [Rey,Emmanuelle,237-26-8494,Hot liner,10]
// [Thomas,Stéphane,967-90-5597,Dessinateur de BD,12]
// [Marie,Thibaut-Pierre,337-90-8653,Formulateur,38]
// [Lagarde,Nathalie,603-77-3947,Archiviste,39]
// [Marchand,Andrée,874-52-0211,Biostatisticien,11]
// [Sanchez,Michel,620-27-7852,Mécanicien d'entretien d'avion,2]
// [du,Manon,787-16-9825,Secrétaire médical,6]
// [Lopes,Raymond,108-37-4758,Prothésiste dentaire,44]
// [Fouquet-Carlier,Guy,380-90-0325,Verrier au chalumeau,41]
// [Lemonnier,Maryse,369-45-2460,Maître-chien,2]
// [Masse,Joséphine,177-28-7986,Opérateur prépresse,36]
// [Michel,Michel,778-62-3421,Orfèvre,38]
// [Maillet-Samson,Henriette,366-32-9214,Chef monteur,7]
// [Alves-Baron,Anaïs,116-59-1326,Substitut du procureur,33]
// [Lemaitre,Juliette,428-80-2832,Horloger,44]
// [Hubert,Nicole,272-18-0975,Marin pêcheur,32]
// [Baron,Xavier,983-68-6775,Encadreur,9]
// [Benard,Paulette,507-67-8018,Ingénieur de la police technique et scientifique,31]
// [Sauvage,Antoine,988-21-2154,Actuaire,21]
// [Ollivier,Bertrand,458-23-1084,Conducteur de machines à imprimer,0]
// [Le,daisy,428-59-8575,Responsable qualité en agroalimentaire,15]
// [du,Capucine,610-26-6635,Matelot,24]
// [Baron,Chantal,094-99-1686,Veilleur stratégique,20]
// [Huet,Gabrielle,782-04-8013,Conseiller en fusion-acquisition,16]
// [Hebert,Denis,041-67-5930,Éducateur de la protection judiciaire de la jeunesse,32]
// [Caron,Cécile,758-24-7116,Aquaculteur,31]
// [Deschamps,Jacques,655-63-1572,Animateur d'activités physiques et sportives,30]
// [Pineau,Michel,712-18-8918,Agent de développement local,17]
// [Pichon,Christine,436-40-5830,Ethnologue,0]
// [Hamel,Inès,679-12-9546,Barman,16]
// [Simon,Jules,054-30-5080,Animateur d'activités physiques et sportives,39]
// [Moreau-Blanchet,Margaret,273-76-0780,Anatomiste,14]
// [Pinto,Élodie,657-69-9593,Économiste de la construction,37]
// [Legendre,Sébastien-Frédéric,243-25-2839,Maraîcher,7]
// [De,Michelle-Nath,096-05-5103,Vendeur en animalerie,38]
// [Vidal,Antoine,215-85-3794,Technico-commercial en agroalimentaire,35]
// [Lesage-Maury,Mathilde,816-31-1592,Concepteur de niveaux de jeu web,1]
// [Cousin,Andrée,840-54-3353,Machiniste constructeur ou plateau,37]
// [Bonneau,Henriette,565-61-8011,Technicien d'analyses biomédicales,6]
// [du,Lucas,440-17-1396,Développeur humanitaire,39]
// [Marchand,Nathalie-Aimée,029-39-5908,Gouvernante,8]
// [Lelievre,Stéphanie,266-78-5275,Ingénieur environnement,31]
// [Olivier-Gay,Audrey,084-71-8125,Scripte,1]
// [Mahe,Hélène,951-69-5949,Chargé des relations publiques,6]
// [Andre,Dorothée,492-63-0080,Chargé de veille législative et réglementaire,26]
// [Colin-Guyot,Lucas,446-60-5568,Maroquinier,18]
// [Goncalves,Laurent,165-71-1371,ingénieur,31]
// [Salmon,Françoise,382-31-9433,Régleur,26]
// [Briand,Élodie,437-37-4441,Modiste,34]
// [Merle,Luce,362-44-4191,Géographe,43]
// [Coste,Victor-Bertrand,529-88-0844,Officier de gendarmerie,34]
// [Delahaye,Georges,705-13-0723,Directeur artistique,4]
// [Fontaine,Diane,562-40-2728,Ingénieur,45]
// [Boucher,Michelle,303-09-7947,Agent de transit,37]
// [du,Henriette,033-86-3844,Comédien,23]
// [Pottier,Léon,931-52-8120,Technicien,33]
// [Dos,Théophile,157-53-1012,Archiviste,9]
// [Descamps,Étienne,563-24-1792,Professeur des écoles,15]
// [Lebreton-Carpentier,Caroline,457-50-5912,Guide conférencier des villes et pays d'art et d'histoire,10]
// [Boutin-Allard,Matthieu,433-57-6869,Technicien paysagiste,37]
// [Imbert,René,322-36-5477,Électricien,24]
// [Remy-Aubry,Hugues,050-41-6891,Hydraulicien,38]
// [Bernier,Bertrand,699-60-5365,Notaire,2]
// [Delattre,Amélie,789-69-6402,Directeur d'hôtel,42]
// [Philippe,Matthieu,113-15-4696,Étalagiste,42]
// [Ferrand-Philippe,Adrienne,225-59-6542,Élagueur,43]
// [Guillou,Franck,232-74-4660,Technicien céramiste,9]
// [Duhamel,Alfred,414-60-3125,Grutier,36]
// [Vidal-Blanc,Jeanne,800-87-8484,Ferronnier d'art,2]
// [Daniel,Adrien,094-20-3850,Conseiller en économie sociale et familiale,36]
// [Leroux,Monique,744-41-9633,Agent de propreté et d'hygiène,20]
// [Guerin,Monique,268-05-9438,Professeur des écoles,12]
// [Bonnet-Faivre,Joseph,578-16-5801,Mécatronicien,18]
// [Moreno,Frédéric,322-61-0692,Conducteur de scierie,7]
// [Ollivier,Franck,289-83-8192,Gardien de la paix,18]
// [de,Bernard,402-27-8517,Hot liner,20]
// [Blanchet,Lorraine,941-82-3517,Officier de gendarmerie,21]
// [Masson,Hortense,738-98-5824,Solier-moquettiste,34]
// [Lebon-Gerard,Étienne,995-87-3015,Accessoiriste,23]
// [Raymond-Fleury,Michelle,923-86-2875,Développeur informatique,39]
// [Descamps-Brunel,Margaud,317-73-9001,Modéliste,7]
// [Courtois,Michel,073-53-2694,Moniteur de ski,23]
// [Navarro,Gabrielle,634-05-0452,Restaurateur d'oeuvres d'art,33]
// [de,Alex,392-38-6174,Tailleur de pierre,12]
// [Poirier,Léon,185-16-7531,Optronicien,31]
// [Allard,Georges,953-15-2235,Responsable biométrie,14]
// [Bourdon,Sylvie,756-42-6054,Responsable du back-office,1]
// [Noel,Isabelle,754-35-3454,Webdesigner,35]
// [Denis,Émile,155-88-9192,Secrétaire juridique,25]
// [Hamel,Éric,894-01-6133,Halieute,42]
// [Leger,Roger,414-58-0598,Réceptionniste,9]
// [Robert,Capucine,518-06-0358,Ingénieur,35]
// [Pires,Nicole,648-55-9425,Modéliste,10]
// [Labbe,Aimé-Franck,965-47-4349,Sous-officier de l'armée de terre,41]
// [Barre,Frédérique-Stéphanie,344-73-5881,Couvreur,7]
// [Guyon,Anastasie,257-28-3154,Acheteur,16]
// [Boulay,Marcel,083-08-1921,Orthoprothésiste,44]
// [Langlois,Antoine-Roger,843-22-6931,Paléontologue,37]
// [Jourdan,Raymond,247-17-5303,Bronzier,4]
// [Vallee,Gabriel,487-52-8669,Tailleur,32]
// [Vincent,Benoît,159-43-2580,Ingénieur en mécanique,10]
// [Barbe,Georges,584-30-4282,Technicien en automatismes,26]
// [Leblanc,Raymond,123-48-1119,Psychologue,27]
// [Gosselin,Capucine,621-35-6122,Directeur d'agence bancaire,15]
// [Louis,Emmanuelle,994-43-8193,Vitrailliste,17]
// [Fabre,Jean,320-30-9324,Ingénieur en construction automobile,19]
// [Maurice,Isaac,914-24-0290,Plombier,12]
// [Caron,Célina,476-97-0727,Opérateur en traitement des matériaux,17]
// [Brunet-Rocher,Michelle,682-25-9627,Peintre en bâtiment,38]
// [Boyer,Agnès,515-71-0418,Accompagnateur de voyages,24]
// [Cordier,Zoé,017-53-6245,Secrétaire juridique,29]
// [Courtois,Antoine-André,893-27-7878,Caissier,5]
// [Durand,Véronique,406-03-3909,Assistant,21]
// [Clerc,Théodore,968-09-2322,Sociologue,6]
// [Faure,Victoire-Aurore,353-80-1375,Conseiller en fusion-acquisition,4]
// [Rocher,Nathalie,519-90-1106,Technicien d'exploitation de l'eau,26]
// [Herve,Agathe,036-18-2679,Médiateur,33]
// [Remy-Normand,Hortense,734-72-3110,Technicien des industries du verre,36]
// [Menard,Virginie,598-30-7892,Hydrogéologue,33]
// [Riviere,Christophe,318-86-2391,Biologiste en environnement,3]
// [Begue,Sophie,707-16-1600,Chef de produit marketing,34]
// [Dufour,Franck,463-62-0982,Dessinateur de BD,29]
// [Legrand,Alphonse,856-09-7647,Ingénieur analyste de l'air,19]
// [Gaudin,Renée,409-32-0091,Conseiller en salle de remise en forme,5]
// [Monnier,Vincent-Marcel,192-88-3829,Réceptionniste,17]
// [Clerc,Denise,418-25-1356,Pilote de ligne automatisée,18]
// [Leroux,Sébastien,803-23-3248,Mécanicien,2]
// [Begue,Mathilde,738-29-8879,Adjoint,2]
// [Perrot,Marguerite,627-71-9085,Agent de service commercial train,27]
// [Fabre,Daniel,652-51-2503,Analyste de crédit,14]
// [Charpentier,Aurore,545-89-6146,Ouvrier,3]
// [Gautier,Marcelle,452-09-1714,Administrateur de logiciels de laboratoire,5]
// [Rodrigues,Gabriel,869-99-9703,Ingénieur technico-commercial en chimie,34]
// [Marin,Sophie,983-16-7501,Façadier,39]
// [Gosselin,Nath,871-39-0063,Chef de produit touristique,17]
// [Normand,Alex,802-62-1883,Caissier,20]
// [Boyer,Lorraine,723-09-4305,Juge d'instance,24]
// [Hebert,Aimée,063-81-7333,Assistant en ressources humaines,28]
// [Monnier,Marthe,461-79-8291,Géologue modélisateur,0]
// [Hardy,Océane,973-26-3991,Responsable de plate-forme biotechnologique,2]
// [de,Suzanne,863-84-9758,Responsable d'ordonnancement,41]
// [Delaunay,Henri,740-29-0167,Conducteur de métro,39]
// [Renault,Jacques,262-07-8169,Sous-officier de l'armée de terre,13]
// [Blot,Maurice,111-41-0070,Sapeur,40]
// [Leveque,Édouard,696-74-7432,Consultant en solutions intégrées,14]
// [Lemonnier-Lemaitre,Emmanuel,542-46-4521,Technicien en engins de travaux publics,15]
// [Adam,Jacqueline,611-04-0213,Constructeur de routes,0]
// [Benard,Édouard,606-77-7053,Directeur de la photographie,34]
// [Barre,William,624-05-5010,Opérateur de raffinerie,25]
// [Roche,Marie,710-24-6898,Installateur en télécoms,12]
// [Chevalier,Élise-Lucy,940-21-1078,Ferronnier d'art,9]
// [Blondel,Hélène,776-45-9762,Télévendeur,15]
// [Remy-Le,Matthieu,934-24-4799,Masseur-kinésithérapeute,23]
// [Martinez,Bernard,413-85-9406,Conducteur de machines à papier,32]
// [Nicolas,Marcel,848-39-0704,Inspecteur du permis de conduire et de la sécurité routière,2]
// [du,Nicolas,542-13-0993,Ingénieur procédés en chimie,41]
// [Mathieu,Jeanne,443-17-0694,Pâtissier,7]
// results = Array([Ruiz,Michelle,561-47-8114,Agent de transit,33], [Lebreton,Alex,658-13-3841,Architecte produit industriel,6], [Lombard,Sophie,981-29-0464,Chercheur en biologie,37], [Bonnin,Élise,035-58-3904,Encadreur,29], [Valentin,Tristan,358-19-7650,Mécatronicien,37], [de,Margaud,143-41-2672,Ingénieur chimiste en développement analytique,1], [Mercier,Martine-Thérèse,938-12-8151,Officier de la marine marchande,11], [Peron,Antoine,385-65-0441,Directeur de création,35], [Chartier,Lucas,356-40-3015,Électromécanicien,34], [Marchand,Émilie,427-32-8671,Assistant,1], [Loiseau,Christophe,987-30-8626,Chercheur en physique,2], [Fabre-Marin,Thérèse,175-24-9412,Ingénieur process aval,15], [Laine,Théophile,412-10-7314,Ingénieur réservoir,46], [Blanchard,Odette,893-1...
// Array([Ruiz,Michelle,561-47-8114,Agent de transit,33], [Lebreton,Alex,658-13-3841,Architecte produit industriel,6], [Lombard,Sophie,981-29-0464,Chercheur en biologie,37], [Bonnin,Élise,035-58-3904,Encadreur,29], [Valentin,Tristan,358-19-7650,Mécatronicien,37], [de,Margaud,143-41-2672,Ingénieur chimiste en développement analytique,1], [Mercier,Martine-Thérèse,938-12-8151,Officier de la marine marchande,11], [Peron,Antoine,385-65-0441,Directeur de création,35], [Chartier,Lucas,356-40-3015,Électromécanicien,34], [Marchand,Émilie,427-32-8671,Assistant,1], [Loiseau,Christophe,987-30-8626,Chercheur en physique,2], [Fabre-Marin,Thérèse,175-24-9412,Ingénieur process aval,15], [Laine,Théophile,412-10-7314,Ingénieur réservoir,46], [Blanchard,Odette,893-1...

// %%
%%dataframe
subDF//.show(truncate=false) // look at parameters
// Out:
// <table><tr><th>last_name</th><th>first_name</th><th>ssn</th><th>occupation</th><th>age</th></tr><tr><td>Ruiz</td><td>Michelle</td><td>561-47-8114</td><td>Agent de transit</td><td>33</td></tr><tr><td>Lebreton</td><td>Alex</td><td>658-13-3841</td><td>Architecte produit industriel</td><td>6</td></tr><tr><td>Lombard</td><td>Sophie</td><td>981-29-0464</td><td>Chercheur en biologie</td><td>37</td></tr><tr><td>Bonnin</td><td>Élise</td><td>035-58-3904</td><td>Encadreur</td><td>29</td></tr><tr><td>Valentin</td><td>Tristan</td><td>358-19-7650</td><td>Mécatronicien</td><td>37</td></tr><tr><td>de</td><td>Margaud</td><td>143-41-2672</td><td>Ingénieur chimiste en développement analytique</td><td>1</td></tr><tr><td>Mercier</td><td>Martine-Thérèse</td><td>938-12-8151</td><td>Officier de la marine marchande</td><td>11</td></tr><tr><td>Peron</td><td>Antoine</td><td>385-65-0441</td><td>Directeur de création</td><td>35</td></tr><tr><td>Chartier</td><td>Lucas</td><td>356-40-3015</td><td>Électromécanicien</td><td>34</td></tr><tr><td>Marchand</td><td>Émilie</td><td>427-32-8671</td><td>Assistant</td><td>1</td></tr></table>

// %% [markdown]
// ## 6. Use _count_ to get total
//
// One of the most basic jobs that we can run is the `count()` job which will count the number of elements in a DataFrame, using the `count()` action. Since `select()` creates a new DataFrame with the same number of elements as the starting DataFrame, we expect that applying `count()` to each DataFrame will return the same result.
//
// <img src="http://spark-mooc.github.io/web-assets/images/cs105x/diagram-3e.png" style="height:750px;float:right"/>
//
// Note that because `count()` is an action operation, if we had not already performed an action with `collect()`, then Spark would now perform the transformation operations when we executed `count()`.
//
// Each task counts the entries in its partition and sends the result to your SparkContext, which adds up all of the counts. The figure on the right shows what would happen if we ran `count()` on a small example dataset with just four partitions.

// %%
println (dataDF.count())
println (subDF.count())
// Out:
// 10000
// 10000

// %% [markdown]
// ## 7. Apply transformation _filter_ and view results with _collect_
//
// Next, we'll create a new DataFrame that only contains the people whose ages are less than 10. To do this, we'll use the `filter()` transformation. (You can also use `where()`, an alias for `filter()`, if you prefer something more SQL-like). The `filter()` method is a transformation operation that creates a new DataFrame from the input DataFrame, keeping only values that match the filter expression.
//
// The figure shows how this might work on the small four-partition dataset.
//
// <img src="http://spark-mooc.github.io/web-assets/images/cs105x/diagram-3f.png" style="height:700px;float:right"/>
//
//
// - To view the filtered list of elements less than 10, we need to create a new list on the driver from the distributed data on the executor nodes.  We use the `collect()` method to return a list that contains all of the elements in this filtered DataFrame to the driver program.

// %%
%%dataframe

val filteredDF = subDF.filter(subDF("age") < 10)
filteredDF//.show(truncate=false)
//filteredDF.count()
// Out:
// <table><tr><th>last_name</th><th>first_name</th><th>ssn</th><th>occupation</th><th>age</th></tr><tr><td>Lebreton</td><td>Alex</td><td>658-13-3841</td><td>Architecte produit industriel</td><td>6</td></tr><tr><td>de</td><td>Margaud</td><td>143-41-2672</td><td>Ingénieur chimiste en développement analytique</td><td>1</td></tr><tr><td>Marchand</td><td>Émilie</td><td>427-32-8671</td><td>Assistant</td><td>1</td></tr><tr><td>Loiseau</td><td>Christophe</td><td>987-30-8626</td><td>Chercheur en physique</td><td>2</td></tr><tr><td>Blanchard</td><td>Odette</td><td>893-14-5482</td><td>Optronicien</td><td>7</td></tr><tr><td>Texier</td><td>David</td><td>096-41-2299</td><td>Responsable de formation</td><td>2</td></tr><tr><td>Fernandes</td><td>Aurélie</td><td>006-81-0101</td><td>Encadreur</td><td>2</td></tr><tr><td>Lamy</td><td>Gilles</td><td>813-72-7015</td><td>Administrateur de spectacle</td><td>8</td></tr><tr><td>Petitjean</td><td>Emmanuel</td><td>310-32-2334</td><td>Hydrologue</td><td>1</td></tr><tr><td>Guilbert</td><td>Élise</td><td>392-99-9718</td><td>Agent de propreté et d'hygiène</td><td>7</td></tr></table>

// %%
filteredDF.count()
// Out:
// 2564

// %% [markdown]
// ## 8. Additional DataFrame actions
//
// Let's investigate some additional actions:
//
// * [first()](http://spark.apache.org/docs/latest/api/scala/index.html#org.apache.spark.sql.Dataset@first():T)
// * [take()](http://spark.apache.org/docs/latest/api/scala/index.html#org.apache.spark.sql.Dataset@take(n:Int):Array[T])
//
// One useful thing to do when we have a new dataset is to look at the first few entries to obtain a rough idea of what information is available.  In Spark, we can do that using actions like `first()`, `take()`, and `show()`. Note that for the `first()` and `take()` actions, the elements that are returned depend on how the DataFrame is *partitioned*.
//
// Instead of using the `collect()` action, we can use the `take(n)` action to return the first _n_ elements of the DataFrame. The `first()` action returns the first element of a DataFrame, and is equivalent to `take(1)[0]`.

// %%
println(s"first: ${filteredDF.first()}")
println(s"Four of them: ${filteredDF.take(4).mkString}")
// Out:
// first: [Lebreton,Alex,658-13-3841,Architecte produit industriel,6]
// Four of them: [Lebreton,Alex,658-13-3841,Architecte produit industriel,6][de,Margaud,143-41-2672,Ingénieur chimiste en développement analytique,1][Marchand,Émilie,427-32-8671,Assistant,1][Loiseau,Christophe,987-30-8626,Chercheur en physique,2]

// %% [markdown]
// ## 9. Additional DataFrame transformations

// %% [markdown]
// ### _orderBy_
//
// [`orderBy()`](http://spark.apache.org/docs/latest/api/scala/index.html#org.apache.spark.sql.Dataset@orderBy(sortExprs:org.apache.spark.sql.Column*):org.apache.spark.sql.Dataset[T]) allows you to sort a DataFrame by one or more columns, producing a new DataFrame.
//
// For example, let's get the first five oldest people in the original (unfiltered) DataFrame. We can use the `orderBy()` transformation. `orderBy` takes one or more columns, either as _names_ (strings) or as `Column` objects. To get a `Column` object, we use one of two notations on the DataFrame:
//
// * Subscript notation: `filteredDF("age")`
//
// Both of those syntaxes return a `Column`, which has additional methods like `desc()` (for sorting in descending order) or `asc()` (for sorting in ascending order, which is the default).
//
// Here are some examples:
//
// ```
// dataDF.orderBy(dataDF("age"))  // sort by age in ascending order; returns a new DataFrame
// dataDF.orderBy(dataDF("last_name").desc) // sort by last name in descending order
// ```

// %%
// Get the five oldest people in the list. To do that, sort by age in descending order.
dataDF.orderBy(dataDF("age").desc).take(5).foreach(println)
// Out:
// [Le,Benjamin,779-72-0132,Éducateur,47]
// [Hamon,Jeannine-Camille,160-85-8720,Enseignant humanitaire,47]
// [Fleury-Pascal,Tristan,749-23-4305,Secrétaire médical,47]
// [Charpentier,Aimée,424-92-6241,Directeur de création,47]
// [Alexandre,Frédérique,818-07-5518,Responsable qualité en agroalimentaire,47]

// %% [markdown]
// ###  _distinct_ and _dropDuplicates_
//
// [`distinct()`](http://spark.apache.org/docs/latest/api/scala/index.html#org.apache.spark.sql.Dataset@distinct():org.apache.spark.sql.Dataset[T]) filters out duplicate rows, and it considers all columns. Since our data is completely randomly generated (by `fake-factory`), it's extremely unlikely that there are any duplicate rows:

// %%
println(dataDF.count())
println(dataDF.distinct().count())
// Out:
// 10000
// 10000

// %% [markdown]
// ### _drop_
//
// [`drop()`](http://spark.apache.org/docs/latest/api/scala/index.html#org.apache.spark.sql.Dataset@drop(col:org.apache.spark.sql.Column):org.apache.spark.sql.DataFrame) is like the opposite of `select()`: Instead of selecting specific columns from a DataFrame, it drops a specifed column from a DataFrame.
//
// Here's a simple use case: Suppose you're reading from a 1,000-column CSV file, and you have to get rid of five of the columns. Instead of selecting 995 of the columns, it's easier just to drop the five you don't want.

// %% [markdown]
// ### _groupBy_
//
// [`groupBy()`](http://spark.apache.org/docs/latest/api/scala/index.html#org.apache.spark.sql.Dataset@groupBy(col1:String,cols:String*):org.apache.spark.sql.RelationalGroupedDataset) is one of the most powerful transformations. It allows you to perform aggregations on a DataFrame.
//
// Unlike other DataFrame transformations, `groupBy()` does _not_ return a DataFrame. Instead, it returns a special [RelationalGroupedDataset](http://spark.apache.org/docs/latest/api/scala/index.html#org.apache.spark.sql.RelationalGroupedDataset) object that contains various aggregation functions.
//
// The most commonly used aggregation function is [count()](http://spark.apache.org/docs/latest/api/scala/index.html#org.apache.spark.sql.RelationalGroupedDataset@count():org.apache.spark.sql.DataFrame),
// but there are others (like [sum()](http://spark.apache.org/docs/latest/api/scala/index.html#org.apache.spark.sql.RelationalGroupedDataset@sum(colNames:String*):org.apache.spark.sql.DataFrame), [max()](http://spark.apache.org/docs/latest/api/scala/index.html#org.apache.spark.sql.RelationalGroupedDataset@max(colNames:String*):org.apache.spark.sql.DataFrame), and [avg()](http://spark.apache.org/docs/latest/api/scala/index.html#org.apache.spark.sql.RelationalGroupedDataset@avg(colNames:String*):org.apache.spark.sql.DataFrame).
//
// These aggregation functions typically create a new column and return a new DataFrame.

// %%
%%dataframe
dataDF.groupBy("occupation").count()//.show(truncate=false)
// Out:
// <table><tr><th>occupation</th><th>count</th></tr><tr><td>Chercheur en physique</td><td>15</td></tr><tr><td>Iconographe</td><td>18</td></tr><tr><td>Chef de station de traitement des eaux</td><td>18</td></tr><tr><td>Officier de l'armée de l'air</td><td>16</td></tr><tr><td>Architecte</td><td>18</td></tr><tr><td>Microtechnicien</td><td>21</td></tr><tr><td>Technicien céramiste</td><td>16</td></tr><tr><td>Officier de marine</td><td>20</td></tr><tr><td>Mécanicien d'entretien d'avion</td><td>16</td></tr><tr><td>Chargé d'études ressources humaines</td><td>14</td></tr></table>

// %% [markdown]
// # Part 3 : WordCount with Dataframes

// %% [markdown]
// **_Create a DataFrame_**
//
// We'll start by generating a base DataFrame by using a List of Strings and the `toDF` method.  Then we'll print out the type and schema of the DataFrame.

// %%
import spark.implicits._
import org.apache.spark.sql._

val wordsDF = List("cat","elephant","rat","rat","cat").toDF("word")
wordsDF.show()
println(wordsDF.getClass)
wordsDF.printSchema()
// Out:
// +--------+
// |    word|
// +--------+
// |     cat|
// |elephant|
// |     rat|
// |     rat|
// |     cat|
// +--------+
//
// class org.apache.spark.sql.Dataset
// root
//  |-- word: string (nullable = true)
// wordsDF = [word: string]
// [word: string]

// %% [markdown]
// ## 1. Counting with Spark SQL and DataFrames
//
// Now, let's count the number of times a particular word appears in the 'word' column. There are multiple ways to perform the counting, but some are much less efficient than others.
//
// A naive approach would be to call `collect` on all of the elements and count them in the driver program. While this approach could work for small datasets, we want an approach that will work for any size dataset including terabyte- or petabyte-sized datasets. In addition, performing all of the work in the driver program is slower than performing it in parallel in the workers. For these reasons, we will use data parallel operations.
//
// **_Using `groupBy` and `count`_**
//
// Using DataFrames, we can perform aggregations by grouping the data using the [`groupBy` function](https://spark.apache.org/docs/latest/api/scala/index.html#org.apache.spark.sql.Dataset@groupBy(col1:String,cols:String*):org.apache.spark.sql.RelationalGroupedDataset) on the DataFrame.  Using `groupBy` returns a [`RelationalGroupedDataset` object](https://spark.apache.org/docs/latest/api/scala/index.html#org.apache.spark.sql.RelationalGroupedDataset) and we can use the functions available for `GroupedData` to aggregate the groups.  For example, we can call `avg` or `count` on a `GroupedData` object to obtain the average of the values in the groups or the number of occurrences in the groups, respectively.
//
// To find the counts of words, group by the words and then use the [`count` function](https://spark.apache.org/docs/latest/api/scala/index.html#org.apache.spark.sql.Dataset@count():Long) to find the number of times that words occur.

// %%
// TODO: Replace ??? with appropriate code
val wordCountsDF = wordsDF.groupBy($"word").count
wordCountsDF.show()
// Out:
// +--------+-----+
// |    word|count|
// +--------+-----+
// |     rat|    2|
// |     cat|    2|
// |elephant|    1|
// +--------+-----+
// wordCountsDF = [word: string, count: bigint]
// [word: string, count: bigint]

// %%
// TEST groupBy and count (2a)
import org.apache.spark.sql.Row
assertResult(List(("cat",2), ("elephant",1), ("rat", 2)), "incorrect counts for wordCountsDF") {
  wordCountsDF.collect().map({case Row(s : String, c : Long) => (s,c.toInt)}).sortBy(_._1).toList
}
// Out:
// 1 test passed

// %% [markdown]
// ## 2. Finding unique words and a mean value
//
// ### _Unique words_
//
// Calculate the number of unique words in `wordsDF`.  You can use other DataFrames that you have already created to make this easier.

// %%
// TODO: Replace ??? with appropriate code
val uniqueWordsCount = wordCountsDF.count
//wordsDF.groupBy($"word").count.count
println(uniqueWordsCount)
// Out:
// 3
// uniqueWordsCount = 3
// 3

// %%
// TEST Unique words
assertResult(3, "incorrect count of unique words") {
  uniqueWordsCount.toInt
}
// Out:
// 1 test passed

// %% [markdown]
// ##  Apply word count to a file

// %% [markdown]
// In this section we will finish developing our word count application.  We'll have to build the `wordCount` function, deal with real world problems like capitalization and punctuation, load in our data source, and compute the word count on the new data.
//
// ###  The `wordCount` function
//
// First, define a function for word counting.  You should reuse the techniques that have been covered in earlier parts of this lab.  This function should take in a DataFrame that is a list of words like `wordsDF` and return a DataFrame that has all of the words and their associated counts.

// %%
// TODO: Replace ??? with appropriate code
def wordCountDF(wordListDF : DataFrame) = {
  /*
Creates a DataFrame with word counts.
Args:
    wordListDF (DataFrame of str): A DataFrame consisting of one string column c
Returns:
    DataFrame of (str, int): A DataFrame containing 'word' and 'count' columns.
   */
 wordListDF.groupBy(wordListDF("word")).count
}
wordCountDF(wordsDF).show()
// Out:
// wordCountDF: (wordListDF: org.apache.spark.sql.DataFrame)org.apache.spark.sql.DataFrame
// +--------+-----+
// |    word|count|
// +--------+-----+
// |     rat|    2|
// |     cat|    2|
// |elephant|    1|
// +--------+-----+

// %%
// TEST wordCount function (4a)
assertResult(List(("cat", 2), ("elephant", 1), ("rat", 2)), "incorrect definition for wordCountDF function") {
  wordCountDF(wordsDF).collect().map({case Row(s : String, c : Long) => (s,c.toInt)}).sortBy(_._1).toList
}
// Out:
// 1 test passed

// %% [markdown]
// ### _Capitalization and punctuation_
//
// Real world files are more complicated than the data we have been using in this lab. Some of the issues we have to address are:
//   + Words should be counted independent of their capitialization (e.g., Spark and spark should be counted as the same word).
//   + All punctuation should be removed.
//   + Any leading or trailing spaces on a line should be removed.
//
// Define the function `removePunctuation` that converts all text to lower case, removes any punctuation, and removes leading and trailing spaces.
//
// To complete this task, you should use Pyspark implemented functions such as :
//
// [regexp_replace](https://spark.apache.org/docs/latest/api/scala/index.html#org.apache.spark.sql.functions$@regexp_replace(e:org.apache.spark.sql.Column,pattern:String,replacement:String):org.apache.spark.sql.Column) module to remove any text that is not a letter, number, or space. If you are unfamiliar with regular expressions, refer to the `removePunctuation` function defined previously in this notebook. You may also want to review [this tutorial](https://developers.google.com/edu/python/regular-expressions) from Google (in Python).  Also, [this website](https://regex101.com/#python) is  a great resource for debugging your regular expression.
//
// You should also use the `trim` and `lower` functions found in [pyspark.sql.functions] in order to lower text and remove leading and trailing spaces. (https://spark.apache.org/docs/latest/api/scala/index.html#org.apache.spark.sql.functions$).
//
// > Note that you shouldn't use any RDD operations or need to create custom user defined functions (udfs) to accomplish this task

// %%
import org.apache.spark.sql.functions._
// TODO: Replace ??? with appropriate code
def removePunctuationDF(coll : Column) = {
  /*
Removes punctuation, changes to lower case, and strips leading and trailing spaces.
Note:
    Only spaces, letters, and numbers should be retained.  Other characters should should be
    eliminated (e.g. it's becomes its).  Leading and trailing spaces should be removed after
    punctuation is removed.
Args:
    column (Column): A Column containing a sentence.
Returns:
    Column: A Column named 'sentence' with clean-up operations applied.
   */
  lower(trim(regexp_replace(coll, "[^\\w\\s\\d]*","")))
}
val sentenceDF = List(("Hi, you!"),(" No under_score!"), (" *      Remove punctuation then spaces  * "))
  .toDF("sentence")
sentenceDF.show(truncate = false)
sentenceDF
  .select(removePunctuationDF(sentenceDF("sentence")))
  .show(truncate = false)
// Out:
// +------------------------------------------+
// |sentence                                  |
// +------------------------------------------+
// |Hi, you!                                  |
// | No under_score!                          |
// | *      Remove punctuation then spaces  * |
// +------------------------------------------+
//
// +---------------------------------------------------+
// |lower(trim(regexp_replace(sentence, [^\w\s\d]*, )))|
// +---------------------------------------------------+
// |hi you                                             |
// |no under_score                                     |
// |remove punctuation then spaces                     |
// +---------------------------------------------------+
// sentenceDF = [sentence: string]
// removePunctuationDF: (coll: org.apache.spark.sql.Column)org.apache.spark.sql.Column
// [sentence: string]

// %% [markdown]
// ### _Load a text file_
//
// For the next part of this lab, we will use the [Complete Works of William Shakespeare](http://www.gutenberg.org/ebooks/100) from [Project Gutenberg](http://www.gutenberg.org/wiki/Main_Page). To convert a text file into a DataFrame, we use the `sqlContext.read.text()` method. We also apply the recently defined `removePunctuation()` function using a `select()` transformation to strip out the punctuation and change all text to lower case.  Since the file is large we use `show(15)`, so that we only print 15 lines.

// %%
val shakespeareDF = spark.sqlContext.read.text(fileName)
  .select(removePunctuationDF(col("value")) as "word")
shakespeareDF.show(15, truncate = false)
// Out:
// +-------------------------------------------------+
// |word                                             |
// +-------------------------------------------------+
// |1609                                             |
// |                                                 |
// |the sonnets                                      |
// |                                                 |
// |by william shakespeare                           |
// |                                                 |
// |                                                 |
// |                                                 |
// |1                                                |
// |from fairest creatures we desire increase        |
// |that thereby beautys rose might never die        |
// |but as the riper should by time decease          |
// |his tender heir might bear his memory            |
// |but thou contracted to thine own bright eyes     |
// |feedst thy lights flame with selfsubstantial fuel|
// +-------------------------------------------------+
// only showing top 15 rows
// shakespeareDF = [word: string]
// lastException: Throwable = null
// [word: string]

// %% [markdown]
// ### _Words from lines_
//
// Before we can use the `wordcount()` function, we have to address two issues with the format of the DataFrame:
//   + The first issue is that  that we need to split each line by its spaces.
//   + The second issue is we need to filter out empty lines or words.
//
// Apply a transformation that will split each 'sentence' in the DataFrame by its spaces, and then transform from a DataFrame that contains lists of words into a DataFrame with each word in its own row.  To accomplish these two tasks you can use the `split` and `explode` functions found in [spark.sql.functions](https://spark.apache.org/docs/latest/api/scala/index.html#org.apache.spark.sql.functions$).
//
// Once you have a DataFrame with one word per row you can apply the [DataFrame operation `where`](https://spark.apache.org/docs/latest/api/scala/index.html#org.apache.spark.sql.Dataset@where(conditionExpr:String):org.apache.spark.sql.Dataset[T]) to remove the rows that contain ''.
//
// > Note that `shakeWordsDF` should be a DataFrame with one column named `word`.

// %%
// TODO: Replace ??? with appropriate code
shakespeareDF.select(split($"word", " ")).show(truncate=false)

val shakeWordsDF :DataFrame = (shakespeareDF
        .select(explode(split($"word", " ")) as "word")
       .where($"word" !== lit(""))
)
shakeWordsDF.show()
val shakeWordsDFCount = shakeWordsDF.count()
println(shakeWordsDFCount)
// Out:
// +---------------------------------------------------------+
// |split(word,  )                                           |
// +---------------------------------------------------------+
// |[1609]                                                   |
// |[]                                                       |
// |[the, sonnets]                                           |
// |[]                                                       |
// |[by, william, shakespeare]                               |
// |[]                                                       |
// |[]                                                       |
// |[]                                                       |
// |[1]                                                      |
// |[from, fairest, creatures, we, desire, increase]         |
// |[that, thereby, beautys, rose, might, never, die]        |
// |[but, as, the, riper, should, by, time, decease]         |
// |[his, tender, heir, might, bear, his, memory]            |
// |[but, thou, contracted, to, thine, own, bright, eyes]    |
// |[feedst, thy, lights, flame, with, selfsubstantial, fuel]|
// |[making, a, famine, where, abundance, lies]              |
// |[thy, self, thy, foe, to, thy, sweet, self, too, cruel]  |
// |[thou, that, art, now, the, worlds, fresh, ornament]     |
// |[and, only, herald, to, the, gaudy, spring]              |
// |[within, thine, own, bud, buriest, thy, content]         |
// +---------------------------------------------------------+
// only showing top 20 rows
//
// +-----------+
// |       word|
// +-----------+
// |       1609|
// |        the|
// |    sonnets|
// |         by|
// |    william|
// |shakespeare|
// |          1|
// |       from|
// |    fairest|
// |  creatures|
// |         we|
// |     desire|
// |   increase|
// |       that|
// |    thereby|
// |    beautys|
// |       rose|
// |      might|
// |      never|
// |        die|
// +-----------+
// only showing top 20 rows
//
// 882996
// shakeWordsDF = [word: string]
// shakeWordsDFCount = 882996
// warning: there was one deprecation warning; re-run with -deprecation for details
// 882996

// %%
// TEST Remove empty elements (4d)
assertResult(882996, "incorrect value for shakeWordCount") {
  shakeWordsDFCount.toInt
}
assertResult(List("word"),"shakeWordsDF should only contain the Column 'word'") {
  shakeWordsDF.columns.toList
}
// Out:
// 1 test passed

// %% [markdown]
// ### _Count the words_
//
// We now have a DataFrame that is only words.  Next, let's apply the `wordCount()` function to produce a list of word counts. We can view the first 20 words by using the `show()` action; however, we'd like to see the words in descending order of count, so we'll need to apply the [`orderBy` DataFrame method](https://spark.apache.org/docs/latest/api/scala/index.html#org.apache.spark.sql.Dataset@orderBy(sortExprs:org.apache.spark.sql.Column*):org.apache.spark.sql.Dataset[T]) to first sort the DataFrame that is returned from `wordCount()`.
//
// You'll notice that many of the words are common English words. These are called stopwords. In a later lab, we will see how to eliminate them from the results.

// %%
%%dataframe
// TODO: Replace ??? with appropriate code
val topWordsAndCountsDF =
  wordCountDF(shakeWordsDF).orderBy($"count" desc)
//

topWordsAndCountsDF//.show()
// Out:
// topWordsAndCountsDF = [word: string, count: bigint]
// warning: there was one feature warning; re-run with -feature for details
// <table><tr><th>word</th><th>count</th></tr><tr><td>the</td><td>27361</td></tr><tr><td>and</td><td>26028</td></tr><tr><td>i</td><td>20681</td></tr><tr><td>to</td><td>19150</td></tr><tr><td>of</td><td>17463</td></tr><tr><td>a</td><td>14593</td></tr><tr><td>you</td><td>13615</td></tr><tr><td>my</td><td>12481</td></tr><tr><td>in</td><td>10956</td></tr><tr><td>that</td><td>10890</td></tr></table>

// %%
// TEST Count the words (4e)
assertResult(
  List(("the", 27361), ("and", 26028), ("i", 20681), ("to", 19150), ("of", 17463),
    ("a", 14593), ("you", 13615), ("my", 12481), ("in", 10956), ("that", 10890),
    ("is", 9134), ("not", 8497), ("with", 7771), ("me", 7769), ("it", 7678)),
  "incorrect value for top15WordsAndCountsDF") {
  topWordsAndCountsDF.take(15).map({
    case Row(s:String,c:Long) => (s,c.toInt)
  }).toList
}
// Out:
// 1 test passed
